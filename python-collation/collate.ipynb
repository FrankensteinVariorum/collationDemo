# %% [markdown]
# # Welcome to *collate.ipynb*!
# *collate.ipynb* is a visual representation of the *collate.py* script -- designed in Jupyter -- to demostrate the Python collation process. Please keep in mind that the following code normally executes when running the *coll.sh* script. Certain pieces of the original code were changed, shifted, or flatout removed for the sake of clarity.
#
# ## Run all of the code below in order!

# %% [markdown]
# ### 1. Libraries and Modules

# %%
# %pip install collateX
# %pip install Levenshtein
from typing import BinaryIO
from collatex import *
from xml.dom import pulldom
import re
# Regular expression operations are very vital, especially when identifying
# and cleaning up nodes that appear in the collation texts
import glob
from datetime import datetime, date
# This library is used to obtain the date and time.
import sys
# The sys library is very important, especially when running 'coll.sh'. 
# This library is used to controls variables and parts of the Python runtime environment
import os
# The os library is used to open, write, and manipulate files located on a local computer.
# Out:
# Requirement already satisfied: collateX in /usr/local/python/3.10.8/lib/python3.10/site-packages (2.2)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.10/site-packages (from collateX) (3.1)
# Requirement already satisfied: prettytable in /usr/local/python/3.10.8/lib/python3.10/site-packages (from collateX) (3.8.0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.10/site-packages (from prettytable->collateX) (0.2.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Levenshtein in /usr/local/python/3.10.8/lib/python3.10/site-packages (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from Levenshtein) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2. Regex nodes and element identifiers

# %%
now = datetime.utcnow()
nowStr = str(now)

print('test: ', dir(Collation))
regexHyphen = re.compile(r'\S[\‑‒–—]\S')
regexWhitespace = re.compile(r'\s+')
regexNonWhitespace = re.compile(r'\S+')
regexEmptyTag = re.compile(r'/>$')
regexBlankLine = re.compile(r'\n{2,}')
regexLeadingBlankLine = re.compile(r'^\n')
regexPageBreak = re.compile(r'<pb.+?/>', re.DOTALL)
RE_MARKUP = re.compile(r'<.+?>', re.DOTALL)
RE_WORD_START = re.compile(r'<w ana="start"/>(.+)<lb[^<>]+>')
RE_WORD_END = re.compile(r'<w ana="end"/>')
# RE_HI_START = re.compile(r'<hi\ssID.+?/>')
# RE_HI_END = re.compile(r'<hi\seID.+?/>')
RE_PARASTART = re.compile(r'<p\ssID.+?/>')
RE_PARAEND = re.compile(r'<p\seID.+?/>')
RE_INCLUDE = re.compile(r'<include.*?/>')
RE_HEAD = re.compile(r'<head.*?/>')
RE_AB = re.compile(r'<ab.*?/>')
# 2018-10-1 ebb: ampersands are apparently not treated in python regex as entities any more than angle brackets.
# RE_AMP_NSB = re.compile(r'\S&amp;\s')
# RE_AMP_NSE = re.compile(r'\s&amp;\S')
# RE_AMP_SQUISH = re.compile(r'\S&amp;\S')
# RE_AMP = re.compile(r'\s&amp;\s')
RE_AMP = re.compile(r'&')
RE_LT_AMP = re.compile(r'&amp;')
# RE_MULTICAPS = re.compile(r'(?<=\W|\s|\>)[A-Z][A-Z]+[A-Z]*\s')
# RE_INNERCAPS = re.compile(r'(?<=hi\d"/>)[A-Z]+[A-Z]+[A-Z]+[A-Z]*')
# TITLE_MultiCaps = match(RE_MULTICAPS).lower()
# RE_NOTE = re.compile(r'<note[^<]*?>.+?</note>', re.MULTILINE | re.DOTALL)
# RE_DEL = re.compile(r'<del[^<\-]*?>.+?</del>', re.MULTILINE | re.DOTALL)
RE_ADDSTART = re.compile(r'<add[^<>]*?>')
RE_ADDEND = re.compile(r'</add>')
RE_NOTE_START = re.compile(r'<note[^<>]+?sID[^<>]+?>')
RE_NOTE_END = re.compile(r'<note[^<>]+?eID[^<>]+?>')
RE_DELSTART = re.compile(r'<del[^<>]*?>')
RE_DELEND = re.compile(r'</del>')
# 2023-05-17 ebb with nlh: We have altered the delSpans thus:
# <delSpan spanTo="id"/> as a start marker and a <delSpan anchor="id"/> in the pre-processed msColl for collation.
# Before the endpoints were <anchor> elements with only xml:ids,
# indistinguishable from the many other anchor elements in the msColl files.
# We want to make it possible for these to be seen in the normalized tokens used in the output collation.
# so they can be displayed as deleted passages in the variant panels.
RE_DELSPAN_START = re.compile(r'<delSpan[^<>]+?spanTo[^<>]+?/>')
RE_DELSPAN_END = re.compile(r'<delSpan[^<>]+?anchor[^<>]+?/>')

RE_ANCHOR = re.compile(r'<anchor.+?/>')
RE_SGA_ADDSTART = re.compile(r'<sga-add[^<>]+?sID[^<>]+?/>')
RE_SGA_ADDEND = re.compile(r'<sga-add[^<>]+?eID[^<>]+?/>')
RE_MDEL = re.compile(r'<mdel[^<>]*?>[^<>]+?</mdel>')
# RE_SHI = re.compile(r'<shi.*?>.+?</shi>')
RE_SHI_START = re.compile(r'<shi[^<>]*?>')
RE_SHI_END = re.compile(r'</shi>')
RE_METAMARK = re.compile(r'<metamark[^<>]*?>.+?</metamark>')
RE_HI = re.compile(r'<hi\s.+?/>')
RE_HI_START = re.compile(r'<hi\s*sID.+?>')
RE_HI_END = re.compile(r'<hi\s*eID.+?>')
RE_PB = re.compile(r'<pb.*?/>')
RE_SPACE_LB = re.compile(r'([\w\s])<lb.*?/>')
RE_LB = re.compile(r'<lb.*?/>')
# ebb: considered: re.DOTALL ? Probably don't need it b/c these regexes are being performed on tokens.
RE_LG = re.compile(r'<lg[^<]*/>')
RE_L = re.compile(r'<l\s[^<]*/>')
RE_CIT = re.compile(r'<cit\s[^<]*/>')
RE_QUOTE = re.compile(r'<quote\s[^<]*/>')
RE_OPENQT = re.compile(r'“')
RE_CLOSEQT = re.compile(r'”')
RE_GAP = re.compile(r'<gap\s[^<]*/>')
# &lt;milestone unit="tei:p"/&gt;
RE_sgaPSTART = re.compile(r'<milestone[^<]+?unit="tei:p-START.+?/>')
RE_sgaPEND = re.compile(r'<milestone[^<]+?unit="tei:p-END.+?/>')
RE_MILESTONE = re.compile(r'<milestone.+?>')
# 2022-07-16 amended 07-31 ebb: Milestone subbing is a special problem: In S-GA paragraphs
# are marked w/ milestone elements with @unit="tei:p"
# and also milestones are used for other things like "tei:seg""
# So we'll do a regex substitution for the paragraphs first, and THEN move to the other milestones.
RE_MOD = re.compile(r'<mod\s[^<]*/>')
RE_MULTI_LEFTANGLE = re.compile(r'<{2,}')
RE_MULTI_RIGHTANGLE = re.compile(r'>{2,}')
RE_LT_START = re.compile(r'<longToken.*?>')
RE_LT_END = re.compile(r'</longToken>')
RE_HEAD_START = re.compile(r'<head.*?>')
RE_HEAD_END = re.compile(r'</head>')
RE_DOTDASH = re.compile(r'\.–')
RE_BIBL = re.compile(r'<bibl.+?>') #Added 2023-07-09 ebb
RE_ZONE = re.compile(r'<zone.+?>') #Added 2023-07-30 ebb

# RE_DOTDASH captures a period followed by a dash, frequently seen in the S-GA edition, and not a word-dividing hyphen.
# 2022-08-08 ebb: I'm currently treating the "dotdash" as just a period for normalization to improve alignments.

# ebb: RE_MDEL = those pesky deletions of two letters or less that we want to normalize out of the collation, but preserve in the output.

# Element types: xml, div, head, p, hi, pb, note, lg, l; comment()
# Tags to ignore, with content to keep: xml, comment, anchor
# Structural elements: div, p, lg, l
# Inline elements (empty) retained in normalization: pb, milestone, xi:include
# Inline and block elements (with content) retained in normalization: note, hi, head, ab

# GIs fall into one three classes
# 2017-05-21 ebb: Due to trouble with pulldom parsing XML comments, I have converted these to comment elements,
# 2017-05-21 ebb: to be ignored during collation.
# 2017-05-30 ebb: Determined that comment elements cannot really be ignored when they have text nodes (the text is
# 2017-05-30 ebb: collated but the tags are not). Decision to make the comments into self-closing elements with text
# 2017-05-30 ebb: contents as attribute values, and content such as tags simplified to be legal attribute values.
# 2017-05-22 ebb: I've set anchor elements with @xml:ids to be the indicators of collation "chunks" to process together
ignore = ['sourceDoc', 'xml', 'comment', 'include', 'addSpan', 'handShift', 'damage', 'unclear', 'restore', 'surface', 'zone', 'retrace']
blockEmpty = ['p', 'div', 'milestone', 'lg', 'l', 'cit', 'quote', 'bibl']
inlineEmpty = ['mod', 'pb', 'sga-add', 'delSpan', 'anchor', 'lb', 'gap', 'hi', 'w', 'ab']
inlineContent = ['del-INNER', 'add-INNER', 'metamark', 'shi']
inlineVariationEvent = ['head', 'del', 'mdel', 'add', 'note', 'longToken']
# Out:
# test:  ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'add_plain_witness', 'add_witness', 'create_from_dict', 'create_from_json']

# %%
def normalizeSpace(inText):
    """ Replaces all whitespace spans with a newline character for tokenization."""
    if regexNonWhitespace.search(inText):
        return regexWhitespace.sub('\n', inText)
    else:
        return ''

# %%
def extract(input_xml):
    """Process entire input XML document, firing on events"""
    # Start pulling; it continues automatically
    doc = pulldom.parse(input_xml)
    output = ''
    for event, node in doc:
        # elements to ignore: xml
        if event == pulldom.START_ELEMENT and node.localName in ignore:
            continue
        # copy comments intact
        # if event == pulldom.COMMENT:
        #     doc.expandNode(node)
        #     output += node.toxml()
        # ebb: The following handles our longToken and longToken-style elements:
        # complete element nodes surrounded by newline characters to make a long complete token:
        if event == pulldom.START_ELEMENT and node.localName in inlineVariationEvent:
            doc.expandNode(node)
            # 2022-10-25 ebb: The line above may be sending the characters inside the node to be processed twice,
            # resulting in the patterns of `&amp;&amp; for a single &amp; or &amp;&amp;quot; and andquot
            # output += '\n' + node.toxml() + '\n'
            # print(node.toxml()); Today, we cannot find a good pre-processing solution, but I hypothesize that
            # we might run this node.toxml() output through a sub function to do the equivalent of
            # the XSLT replace() we're now doing to handle this problem in post-processing.
            output += '\n' + node.toxml() + '\n'
            # output += '\n' + node.toxml()
        # ebb: Next (below): empty block elements: pb, milestone, lb, lg, l, p, ab, hi,
        # We COULD set white spaces around these like this ' ' + node.toxml() + ' '
        # but what seems to happen is that the white spaces get added to tokens; they aren't used to
        # isolate the markup into separate tokens, which is really what we'd want.
        # So, I'm removing the white spaces here.
        # NOTE: Removing the white space seems to improve/expand app alignment
        # 2022-07-16 ebb: With help from yxj, found that adding \n to each side of blockEmpty and inlineEmpty elements
        # stops the problem of forming tokens that fuse element tags to words.
        elif event == pulldom.START_ELEMENT and node.localName in blockEmpty:
            output += '\n' + node.toxml() + '\n'
        # ebb: empty inline elements that do not take surrounding white spaces:
        elif event == pulldom.START_ELEMENT and node.localName in inlineEmpty:
            output += node.toxml()
        # non-empty inline elements: mdel, shi, metamark
        elif event == pulldom.START_ELEMENT and node.localName in inlineContent:
            output += '\n' + regexEmptyTag.sub('>', node.toxml())
            # output += '\n' + node.toxml()
        elif event == pulldom.END_ELEMENT and node.localName in inlineContent:
            output += '</' + node.localName + '>' + '\n'
        # elif event == pulldom.START_ELEMENT and node.localName in blockElement:
        #    output += '\n<' + node.localName + '>\n'
        # elif event == pulldom.END_ELEMENT and node.localName in blockElement:
        #    output += '\n</' + node.localName + '>'
        elif event == pulldom.CHARACTERS:
            # output += fixToken(normalizeSpace(node.data))
            output += normalizeSpace(node.data)

        else:
            continue
    return output

# %%
inputText = "The quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog."

def normalize(inputText):
    # 2022-07-16 ebb: Adding newlines here is too late: it just inserts a newline into a token.
    # 2022-08-06 ebb: I have rewritten this series of operations using a normalized variable for legibility.
    # These need to run in sequence: the order of replacements matters.
    # The lower() at the end lowercases all the normalized strings to simplify the comparison.

    normalized = RE_METAMARK.sub('', inputText)
    normalized = RE_MOD.sub('', normalized)
    # 2023-03-16 How about we actually read it this time? <mod> is in the ignore list like anchor, etc, so why are we presuming it's being read?
    normalized = RE_GAP.sub('', normalized)
    normalized = RE_CLOSEQT.sub('"', normalized)
    normalized = RE_OPENQT.sub('"', normalized)
    normalized = RE_QUOTE.sub('', normalized)
    normalized = RE_CIT.sub('', normalized)
    normalized = RE_BIBL.sub('', normalized) # Added 2023-07-29 ebb
    normalized = RE_L.sub('<l/>', normalized)
    normalized = RE_LG.sub('<lg/>', normalized)
    normalized = RE_AB.sub('', normalized)
    # 2022-08-06 <ab> wraps headings or starts of letters in the print editions
    normalized = RE_PARASTART.sub('<p-start/>', normalized)
    normalized = RE_PARAEND.sub('<p-end/>', normalized)
    normalized = RE_sgaPSTART.sub('<p-start/>', normalized)
    normalized = RE_sgaPEND.sub('<p-end/>', normalized)
    normalized = RE_MILESTONE.sub('', normalized)
    normalized = RE_PB.sub('', normalized)
    # 2023-05-17 ebb with nlh: Noting that delSpan needs a way to be expressed
    # in the output normalized tokens for the new interface.
    # Freshly altered delSpan and anchor in msColl files to delspan...delspan, normalizing in next two lines:
    normalized = RE_DELSPAN_START.sub('<del>', normalized)
    normalized = RE_DELSPAN_END.sub('</del>', normalized)
    normalized = RE_ANCHOR.sub('', normalized)
    normalized = RE_LT_AMP.sub('and', normalized)
    normalized = RE_AMP.sub('and', normalized)
    normalized = RE_WORD_START.sub(' \\1', normalized)
    # 2023-05-22 ebb and yxj: We must replace WORD_START before the SPACE_LB.
    # WORD_START replacement ensures that the normalized token for <w ana='start'/>...<lb/>...<w ana="end"/>
    # does not get an added space. We need to ensure that these are treated as single word tokens
    # with no space added internally.
    normalized = RE_WORD_END.sub(' ', normalized)
    normalized = RE_SPACE_LB.sub('\\1 ', normalized)
    normalized = RE_LB.sub('', normalized)
    normalized = RE_ZONE.sub('', normalized)
    normalized = RE_NOTE_START.sub('<note>', normalized)
    normalized = RE_NOTE_END.sub('</note>', normalized)
    normalized = RE_SGA_ADDSTART.sub('', normalized)
    normalized = RE_SGA_ADDEND.sub('', normalized)
    normalized = RE_ADDSTART.sub('', normalized)
    normalized = RE_ADDEND.sub('', normalized)
    normalized = RE_DELSTART.sub('<del>', normalized)
    normalized = RE_DELEND.sub('</del>', normalized)
    normalized = RE_LT_START.sub('', normalized)
    normalized = RE_LT_END.sub('', normalized)
    normalized = RE_HEAD_START.sub('', normalized)
    normalized = RE_HEAD_END.sub('', normalized)
    # 2023-06-30 nlh: added space inside <hi/> normalization.
    normalized = RE_HI_START.sub('<hi>', normalized) # ebb: 2023-07-30 We used to normalize <hi> as a space, but we're going to try supplying it as a start and end tag for the normalized tokens now.
    normalized = RE_HI_END.sub('</hi>', normalized)
    # 2022-08-08 ebb: Sometimes <hi> in the print editions seems irrelevant, in highlighting words at
    # chapter beginnings. However, it also sometimes indicates emphasis on a word.
    # Example: one or two little <hi sID="xxx"/>wives<hi eID="novel1_letter4_chapter6_div4_div6_p9_hi1"/>
    # On analysis of <hi> and <shi> in the print and SG-A editions, it is difficult to distinguish
    # meaningful highlights from conventional superscripts/underlining, so it seems best to ignore it in normalization,
    # or return to the source texts and add markup to distinguish passages giving emphasis.
    #  normalized = RE_SHI.sub('', normalized)
    normalized = RE_SHI_START.sub('', normalized)
    normalized = RE_SHI_END.sub('', normalized)
    # 2022-08-08 ebb: <shi> elements mark briefly highlighted words or passages in the S-GA edition.
    # The highlights themselves are not usually significant, but the text inside must be preserved for comparison.
    # Example: <shi rend="underline">should be</shi>
    # Previously, we were eliminating these passages entirely from the normalization, which was a serious error!
    # We have not been considering highlighting or emphasis <hi> or <shi> as a significant difference in the normalization.
    # 2023-03-16 ebb: We have moved mdel to inlineVariationEvent, and do not want to normalize its token, so we are commenting out the next line.
    # normalized = RE_MDEL.sub('', normalized)
    # 2022-08-08 ebb: <mdel> elements are tiny struck-out characters in the S-GA edition.
    # We do not think these are significant for comparison with the other editions, so we normalize them out.
    normalized = RE_DOTDASH.sub('. ', normalized)
    normalized = RE_INCLUDE.sub('', normalized)
    normalized = RE_MULTI_RIGHTANGLE.sub('>', normalized)
    normalized = RE_MULTI_LEFTANGLE.sub('<', normalized)
    normalized = re.sub(r'^\s+', '', normalized) # 2023-06-26 yxj: remvoe the space at the beginning
    normalized = re.sub(r'\s+$', '', normalized) # 2023-06-26 yxj: remvoe the space at the end
    normalized = normalized.lower()
    print(normalized)
    return normalized

normalize(inputText)
# Out:
# the quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog.
# 'the quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog.'

# %%
def processToken(inputText):
    print({"t": inputText + ' ', "n": normalize(inputText)})
    return {"t": inputText + ' ', "n": normalize(inputText)}


def processWitness(inputWitness, id):
    return {'id': id, 'tokens': [processToken(token) for token in inputWitness]}


def tokenize(inputFile):
    return regexLeadingBlankLine.sub('\n', regexBlankLine.sub('\n', extract(inputFile))).split('\n')

def tokenizeFiles(f1818, f1823, fThomas, f1831, fMS):
    with open(f1818, 'rb') as f1818file, \
            open(f1823, 'rb') as f1823file, \
            open(fThomas, 'rb') as fThomasfile, \
            open(f1831, 'rb') as f1831file, \
            open(fMS, 'rb') as fMSfile:
        f1818_tokenlist = processWitness(tokenize(f1818file), 'f1818')
        fThomas_tokenlist = processWitness(tokenize(fThomasfile), 'fThomas')
        f1823_tokenlist = processWitness(tokenize(f1823file), 'f1823')
        f1831_tokenlist = processWitness(tokenize(f1831file), 'f1831')
        fMS_tokenlist = processWitness(tokenize(fMSfile), 'fMS')
        print(fThomas_tokenlist)
        return [f1818_tokenlist, f1823_tokenlist, fThomas_tokenlist, f1831_tokenlist, fMS_tokenlist]
processToken(inputText)
# Out:
# the quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog.
# {'t': 'The quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog. ', 'n': 'the quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog.'}
# the quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog.
# {'t': 'The quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog. ',
#  'n': 'the quick <gap/> <quote>brown</quote> <ab>fox jumped</ab> over the lazy dog.'}

# %% [markdown]
# ### Collation of a complete "chunk" in Frankenstein
#
# The following cell collates five versions of a "chunk" (or an aligned unit, usually a chapter) in Frankenstein.

# %%
# For this example, chunk is set to C18. In other words, when this function runs, it will process Chunk 18.
chunk = 'C01'
# Normally, this chunk variable would be assigned an agrument variable given by the shell script:
# chunk = sys.argv[1]
for f1818 in glob.glob('../collationChunks/' + chunk + '/input/1818_fullFlat_*'):
    try:
        collChunk = f1818.split("fullFlat_", 1)[1]
        # ebb: above gets C30.xml for example
        # matchStr = matchString.split(".", 1)[0]
        # ebb: above strips off the file extension

        f1823 = '../collationChunks/' + chunk + '/input/1823_fullFlat_' + collChunk
        fThomas = '../collationChunks/' + chunk + '/input/Thomas_fullFlat_' + collChunk
        f1831 = '../collationChunks/' + chunk + '/input/1831_fullFlat_' + collChunk
        fMS = '../collationChunks/' + chunk + '/input/msColl_' + collChunk
        # 2023-05-17 ebb: **Before we begin the tokenizing**, run a XSLT pre-processing pass:
        # Revise delSpan anchor elements and remove newlines from inlineVariationEvent elements so these hold together as long tokens:

        tokenLists = tokenizeFiles(f1818, f1823, fThomas, f1831, fMS)
        print(tokenLists)
        # 2022-11-14 yxj: For easier doing unit testing,
        # can we import 4 filenames instead of only 1 into tokenizeFiles()?

        collation_input = {"witnesses": tokenLists}
        outputFile = open('../collationChunks/' + chunk + '/output/Collation_' + chunk + '-partway.xml', 'w', encoding='utf-8')
        
            # table = collate(collation_input, output='tei', segmentation=True)
            # table = collate(collation_input, segmentation=True, layout='vertical')
        table = collate(collation_input, output='xml', segmentation=True)
        outputFile.close()

    except IOError:
        pass
# Out:
# {'t': ' ', 'n': ''}
#
#
# {'t': '<milestone unit="volume" n="1"/> ', 'n': ''}
#
#
# {'t': '<milestone unit="frontmatter" type="start" n="1"/> ', 'n': ''}
#
#
# {'t': '<milestone unit="frontmatter" type="end" n="1"/> ', 'n': ''}
#
#
# {'t': '<milestone unit="preface" type="start" n="1"/> ', 'n': ''}
#
#
# {'t': '<pb xml:id="F1818_v1_007" n="viii"/> ', 'n': ''}
#
# preface.
# {'t': '<head>PREFACE.</head> ', 'n': 'preface.'}
# preface.
# <p-start/>
# {'t': '<p sID="preface1_p1"/> ', 'n': '<p-start/>'}
# <p-start/>
# t<hi>he</hi>
# {'t': 'T<hi sID="preface1_p1_hi1"/>HE<hi eID="preface1_p1_hi1"/> ', 'n': 't<hi>he</hi>'}
# t<hi>he</hi>
# event
# {'t': 'event ', 'n': 'event'}
# event
# on
# {'t': 'on ', 'n': 'on'}
# on
# which
# {'t': 'which ', 'n': 'which'}
# which
# this
# {'t': 'this ', 'n': 'this'}
# this
# fiction
# {'t': 'fiction ', 'n': 'fiction'}
# fiction
# is
# {'t': 'is ', 'n': 'is'}
# is
# founded
# {'t': 'founded ', 'n': 'founded'}
# founded
# has
# {'t': 'has ', 'n': 'has'}
# has
# been
# {'t': 'been ', 'n': 'been'}
# been
# supposed,
# {'t': 'supposed, ', 'n': 'supposed,'}
# supposed,
# by
# {'t': 'by ', 'n': 'by'}
# by
# dr.
# {'t': 'Dr. ', 'n': 'dr.'}
# dr.
# darwin,
# {'t': 'Darwin, ', 'n': 'darwin,'}
# darwin,
# and
# {'t': 'and ', 'n': 'and'}
# and
# some
# {'t': 'some ', 'n': 'some'}
# some
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# physiological
# {'t': 'physiological ', 'n': 'physiological'}
# physiological
# writers
# {'t': 'writers ', 'n': 'writers'}
# writers
# of
# {'t': 'of ', 'n': 'of'}
# of
# germany,
# {'t': 'Germany, ', 'n': 'germany,'}
# germany,
# as
# {'t': 'as ', 'n': 'as'}
# as
# not
# {'t': 'not ', 'n': 'not'}
# not
# of
# {'t': 'of ', 'n': 'of'}
# of
# impossible
# {'t': 'impossible ', 'n': 'impossible'}
# impossible
# occurrence.
# {'t': 'occurrence. ', 'n': 'occurrence.'}
# occurrence.
# i
# {'t': 'I ', 'n': 'i'}
# i
# shall
# {'t': 'shall ', 'n': 'shall'}
# shall
# not
# {'t': 'not ', 'n': 'not'}
# not
# be
# {'t': 'be ', 'n': 'be'}
# be
# supposed
# {'t': 'supposed ', 'n': 'supposed'}
# supposed
# as
# {'t': 'as ', 'n': 'as'}
# as
# according
# {'t': 'according ', 'n': 'according'}
# according
# the
# {'t': 'the ', 'n': 'the'}
# the
# remotest
# {'t': 'remotest ', 'n': 'remotest'}
# remotest
# degree
# {'t': 'degree ', 'n': 'degree'}
# degree
# of
# {'t': 'of ', 'n': 'of'}
# of
# serious
# {'t': 'serious ', 'n': 'serious'}
# serious
# faith
# {'t': 'faith ', 'n': 'faith'}
# faith
# to
# {'t': 'to ', 'n': 'to'}
# to
# such
# {'t': 'such ', 'n': 'such'}
# such
# an
# {'t': 'an ', 'n': 'an'}
# an
# imagination;
# {'t': 'imagination; ', 'n': 'imagination;'}
# imagination;
# yet,
# {'t': 'yet, ', 'n': 'yet,'}
# yet,
# in
# {'t': 'in ', 'n': 'in'}
# in
# assuming
# {'t': 'assuming ', 'n': 'assuming'}
# assuming
# it
# {'t': 'it ', 'n': 'it'}
# it
# as
# {'t': 'as ', 'n': 'as'}
# as
# the
# {'t': 'the ', 'n': 'the'}
# the
# basis
# {'t': 'basis ', 'n': 'basis'}
# basis
# of
# {'t': 'of ', 'n': 'of'}
# of
# a
# {'t': 'a ', 'n': 'a'}
# a
# work
# {'t': 'work ', 'n': 'work'}
# work
# of
# {'t': 'of ', 'n': 'of'}
# of
# fancy,
# {'t': 'fancy, ', 'n': 'fancy,'}
# fancy,
# i
# {'t': 'I ', 'n': 'i'}
# i
# have
# {'t': 'have ', 'n': 'have'}
# have
# not
# {'t': 'not ', 'n': 'not'}
# not
# considered
# {'t': 'considered ', 'n': 'considered'}
# considered
# myself
# {'t': 'myself ', 'n': 'myself'}
# myself
# as
# {'t': 'as ', 'n': 'as'}
# as
# merely
# {'t': 'merely ', 'n': 'merely'}
# merely
# weaving
# {'t': 'weaving ', 'n': 'weaving'}
# weaving
# a
# {'t': 'a ', 'n': 'a'}
# a
# series
# {'t': 'series ', 'n': 'series'}
# series
# of
# {'t': 'of ', 'n': 'of'}
# of
# supernatural
# {'t': 'supernatural ', 'n': 'supernatural'}
# supernatural
# terrors.
# {'t': 'terrors. ', 'n': 'terrors.'}
# terrors.
# the
# {'t': 'The ', 'n': 'the'}
# the
# event
# {'t': 'event ', 'n': 'event'}
# event
# on
# {'t': 'on ', 'n': 'on'}
# on
# which
# {'t': '<pb xml:id="F1818_v1_008" n="viii"/>which ', 'n': 'which'}
# which
# the
# {'t': 'the ', 'n': 'the'}
# the
# interest
# {'t': 'interest ', 'n': 'interest'}
# interest
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# story
# {'t': 'story ', 'n': 'story'}
# story
# depends
# {'t': 'depends ', 'n': 'depends'}
# depends
# is
# {'t': 'is ', 'n': 'is'}
# is
# exempt
# {'t': 'exempt ', 'n': 'exempt'}
# exempt
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# disadvantages
# {'t': 'disadvantages ', 'n': 'disadvantages'}
# disadvantages
# of
# {'t': 'of ', 'n': 'of'}
# of
# a
# {'t': 'a ', 'n': 'a'}
# a
# mere
# {'t': 'mere ', 'n': 'mere'}
# mere
# tale
# {'t': 'tale ', 'n': 'tale'}
# tale
# of
# {'t': 'of ', 'n': 'of'}
# of
# spectres
# {'t': 'spectres ', 'n': 'spectres'}
# spectres
# or
# {'t': 'or ', 'n': 'or'}
# or
# enchantment.
# {'t': 'enchantment. ', 'n': 'enchantment.'}
# enchantment.
# it
# {'t': 'It ', 'n': 'it'}
# it
# was
# {'t': 'was ', 'n': 'was'}
# was
# recommended
# {'t': 'recommended ', 'n': 'recommended'}
# recommended
# by
# {'t': 'by ', 'n': 'by'}
# by
# the
# {'t': 'the ', 'n': 'the'}
# the
# novelty
# {'t': 'novelty ', 'n': 'novelty'}
# novelty
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# situations
# {'t': 'situations ', 'n': 'situations'}
# situations
# which
# {'t': 'which ', 'n': 'which'}
# which
# it
# {'t': 'it ', 'n': 'it'}
# it
# developes;
# {'t': 'developes; ', 'n': 'developes;'}
# developes;
# and,
# {'t': 'and, ', 'n': 'and,'}
# and,
# however
# {'t': 'however ', 'n': 'however'}
# however
# impossible
# {'t': 'impossible ', 'n': 'impossible'}
# impossible
# as
# {'t': 'as ', 'n': 'as'}
# as
# a
# {'t': 'a ', 'n': 'a'}
# a
# physical
# {'t': 'physical ', 'n': 'physical'}
# physical
# fact,
# {'t': 'fact, ', 'n': 'fact,'}
# fact,
# affords
# {'t': 'affords ', 'n': 'affords'}
# affords
# a
# {'t': 'a ', 'n': 'a'}
# a
# point
# {'t': 'point ', 'n': 'point'}
# point
# of
# {'t': 'of ', 'n': 'of'}
# of
# view
# {'t': 'view ', 'n': 'view'}
# view
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# imagination
# {'t': 'imagination ', 'n': 'imagination'}
# imagination
# for
# {'t': 'for ', 'n': 'for'}
# for
# the
# {'t': 'the ', 'n': 'the'}
# the
# delineating
# {'t': 'delineating ', 'n': 'delineating'}
# delineating
# of
# {'t': 'of ', 'n': 'of'}
# of
# human
# {'t': 'human ', 'n': 'human'}
# human
# passions
# {'t': 'passions ', 'n': 'passions'}
# passions
# more
# {'t': 'more ', 'n': 'more'}
# more
# comprehensive
# {'t': 'comprehensive ', 'n': 'comprehensive'}
# comprehensive
# and
# {'t': 'and ', 'n': 'and'}
# and
# commanding
# {'t': 'commanding ', 'n': 'commanding'}
# commanding
# than
# {'t': 'than ', 'n': 'than'}
# than
# any
# {'t': 'any ', 'n': 'any'}
# any
# which
# {'t': 'which ', 'n': 'which'}
# which
# the
# {'t': 'the ', 'n': 'the'}
# the
# ordinary
# {'t': 'ordinary ', 'n': 'ordinary'}
# ordinary
# relations
# {'t': 'relations ', 'n': 'relations'}
# relations
# of
# {'t': 'of ', 'n': 'of'}
# of
# existing
# {'t': 'existing ', 'n': 'existing'}
# existing
# events
# {'t': 'events ', 'n': 'events'}
# events
# can
# {'t': 'can ', 'n': 'can'}
# can
# yield.
# {'t': 'yield. ', 'n': 'yield.'}
# yield.
# <p-end/>
# {'t': '<p eID="preface1_p1"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p2"/> ', 'n': '<p-start/>'}
# <p-start/>
# i
# {'t': 'I ', 'n': 'i'}
# i
# have
# {'t': 'have ', 'n': 'have'}
# have
# thus
# {'t': 'thus ', 'n': 'thus'}
# thus
# endeavoured
# {'t': 'endeavoured ', 'n': 'endeavoured'}
# endeavoured
# to
# {'t': 'to ', 'n': 'to'}
# to
# preserve
# {'t': 'preserve ', 'n': 'preserve'}
# preserve
# the
# {'t': 'the ', 'n': 'the'}
# the
# truth
# {'t': 'truth ', 'n': 'truth'}
# truth
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# elementary
# {'t': 'elementary ', 'n': 'elementary'}
# elementary
# principles
# {'t': 'principles ', 'n': 'principles'}
# principles
# of
# {'t': 'of ', 'n': 'of'}
# of
# human
# {'t': 'human ', 'n': 'human'}
# human
# nature,
# {'t': 'nature, ', 'n': 'nature,'}
# nature,
# while
# {'t': 'while ', 'n': 'while'}
# while
# i
# {'t': 'I ', 'n': 'i'}
# i
# have
# {'t': 'have ', 'n': 'have'}
# have
# not
# {'t': 'not ', 'n': 'not'}
# not
# scrupled
# {'t': 'scrupled ', 'n': 'scrupled'}
# scrupled
# to
# {'t': 'to ', 'n': 'to'}
# to
# innovate
# {'t': 'innovate ', 'n': 'innovate'}
# innovate
# upon
# {'t': 'upon ', 'n': 'upon'}
# upon
# their
# {'t': 'their ', 'n': 'their'}
# their
# combinations.
# {'t': 'combinations. ', 'n': 'combinations.'}
# combinations.
# the
# {'t': 'The ', 'n': 'the'}
# the
# <hi>iliad</hi>,
# {'t': '<hi sID="preface1_p2_hi1"/>Iliad<hi eID="preface1_p2_hi1"/>, ', 'n': '<hi>iliad</hi>,'}
# <hi>iliad</hi>,
# the
# {'t': 'the ', 'n': 'the'}
# the
# tragic
# {'t': 'tragic ', 'n': 'tragic'}
# tragic
# poetry
# {'t': 'poetry ', 'n': 'poetry'}
# poetry
# of
# {'t': 'of ', 'n': 'of'}
# of
# greece,—shakespeare,
# {'t': 'Greece,—Shakespeare, ', 'n': 'greece,—shakespeare,'}
# greece,—shakespeare,
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# <hi>tempest</hi>
# {'t': '<hi sID="preface1_p2_hi2"/>Tempest<hi eID="preface1_p2_hi2"/> ', 'n': '<hi>tempest</hi>'}
# <hi>tempest</hi>
# and
# {'t': 'and ', 'n': 'and'}
# and
# <hi>midsummer
# {'t': '<hi sID="preface1_p2_hi3"/>Mid<pb xml:id="F1818_v1_009" n="ix"/>summer ', 'n': '<hi>midsummer'}
# <hi>midsummer
# night’s
# {'t': 'Night’s ', 'n': 'night’s'}
# night’s
# dream</hi>,—and
# {'t': 'Dream<hi eID="preface1_p2_hi3"/>,—and ', 'n': 'dream</hi>,—and'}
# dream</hi>,—and
# most
# {'t': 'most ', 'n': 'most'}
# most
# especially
# {'t': 'especially ', 'n': 'especially'}
# especially
# milton,
# {'t': 'Milton, ', 'n': 'milton,'}
# milton,
# in
# {'t': 'in ', 'n': 'in'}
# in
# <hi>paradise
# {'t': '<hi sID="preface1_p2_hi4"/>Paradise ', 'n': '<hi>paradise'}
# <hi>paradise
# lost</hi>,
# {'t': 'Lost<hi eID="preface1_p2_hi4"/>, ', 'n': 'lost</hi>,'}
# lost</hi>,
# conform
# {'t': 'conform ', 'n': 'conform'}
# conform
# to
# {'t': 'to ', 'n': 'to'}
# to
# this
# {'t': 'this ', 'n': 'this'}
# this
# rule;
# {'t': 'rule; ', 'n': 'rule;'}
# rule;
# and
# {'t': 'and ', 'n': 'and'}
# and
# the
# {'t': 'the ', 'n': 'the'}
# the
# most
# {'t': 'most ', 'n': 'most'}
# most
# humble
# {'t': 'humble ', 'n': 'humble'}
# humble
# novelist,
# {'t': 'novelist, ', 'n': 'novelist,'}
# novelist,
# who
# {'t': 'who ', 'n': 'who'}
# who
# seeks
# {'t': 'seeks ', 'n': 'seeks'}
# seeks
# to
# {'t': 'to ', 'n': 'to'}
# to
# confer
# {'t': 'confer ', 'n': 'confer'}
# confer
# or
# {'t': 'or ', 'n': 'or'}
# or
# receive
# {'t': 'receive ', 'n': 'receive'}
# receive
# amusement
# {'t': 'amusement ', 'n': 'amusement'}
# amusement
# from
# {'t': 'from ', 'n': 'from'}
# from
# his
# {'t': 'his ', 'n': 'his'}
# his
# labours,
# {'t': 'labours, ', 'n': 'labours,'}
# labours,
# may,
# {'t': 'may, ', 'n': 'may,'}
# may,
# without
# {'t': 'without ', 'n': 'without'}
# without
# presumption,
# {'t': 'presumption, ', 'n': 'presumption,'}
# presumption,
# apply
# {'t': 'apply ', 'n': 'apply'}
# apply
# to
# {'t': 'to ', 'n': 'to'}
# to
# prose
# {'t': 'prose ', 'n': 'prose'}
# prose
# fiction
# {'t': 'fiction ', 'n': 'fiction'}
# fiction
# a
# {'t': 'a ', 'n': 'a'}
# a
# licence,
# {'t': 'licence, ', 'n': 'licence,'}
# licence,
# or
# {'t': 'or ', 'n': 'or'}
# or
# rather
# {'t': 'rather ', 'n': 'rather'}
# rather
# a
# {'t': 'a ', 'n': 'a'}
# a
# rule,
# {'t': 'rule, ', 'n': 'rule,'}
# rule,
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# adoption
# {'t': 'adoption ', 'n': 'adoption'}
# adoption
# of
# {'t': 'of ', 'n': 'of'}
# of
# which
# {'t': 'which ', 'n': 'which'}
# which
# so
# {'t': 'so ', 'n': 'so'}
# so
# many
# {'t': 'many ', 'n': 'many'}
# many
# exquisite
# {'t': 'exquisite ', 'n': 'exquisite'}
# exquisite
# combinations
# {'t': 'combinations ', 'n': 'combinations'}
# combinations
# of
# {'t': 'of ', 'n': 'of'}
# of
# human
# {'t': 'human ', 'n': 'human'}
# human
# feeling
# {'t': 'feeling ', 'n': 'feeling'}
# feeling
# have
# {'t': 'have ', 'n': 'have'}
# have
# resulted
# {'t': 'resulted ', 'n': 'resulted'}
# resulted
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# highest
# {'t': 'highest ', 'n': 'highest'}
# highest
# specimens
# {'t': 'specimens ', 'n': 'specimens'}
# specimens
# of
# {'t': 'of ', 'n': 'of'}
# of
# poetry.
# {'t': 'poetry. ', 'n': 'poetry.'}
# poetry.
# <p-end/>
# {'t': '<p eID="preface1_p2"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p3"/> ', 'n': '<p-start/>'}
# <p-start/>
# the
# {'t': 'The ', 'n': 'the'}
# the
# circumstance
# {'t': 'circumstance ', 'n': 'circumstance'}
# circumstance
# on
# {'t': 'on ', 'n': 'on'}
# on
# which
# {'t': 'which ', 'n': 'which'}
# which
# my
# {'t': 'my ', 'n': 'my'}
# my
# story
# {'t': 'story ', 'n': 'story'}
# story
# rests
# {'t': 'rests ', 'n': 'rests'}
# rests
# was
# {'t': 'was ', 'n': 'was'}
# was
# suggested
# {'t': 'suggested ', 'n': 'suggested'}
# suggested
# in
# {'t': 'in ', 'n': 'in'}
# in
# casual
# {'t': 'casual ', 'n': 'casual'}
# casual
# conversation.
# {'t': 'conversation. ', 'n': 'conversation.'}
# conversation.
# it
# {'t': 'It ', 'n': 'it'}
# it
# was
# {'t': 'was ', 'n': 'was'}
# was
# commenced
# {'t': 'commenced ', 'n': 'commenced'}
# commenced
# partly
# {'t': 'partly ', 'n': 'partly'}
# partly
# as
# {'t': 'as ', 'n': 'as'}
# as
# a
# {'t': 'a ', 'n': 'a'}
# a
# source
# {'t': 'source ', 'n': 'source'}
# source
# of
# {'t': 'of ', 'n': 'of'}
# of
# amusement,
# {'t': 'amusement, ', 'n': 'amusement,'}
# amusement,
# and
# {'t': 'and ', 'n': 'and'}
# and
# partly
# {'t': 'partly ', 'n': 'partly'}
# partly
# as
# {'t': 'as ', 'n': 'as'}
# as
# an
# {'t': 'an ', 'n': 'an'}
# an
# expedient
# {'t': 'expedient ', 'n': 'expedient'}
# expedient
# for
# {'t': 'for ', 'n': 'for'}
# for
# exercising
# {'t': 'exercising ', 'n': 'exercising'}
# exercising
# any
# {'t': 'any ', 'n': 'any'}
# any
# untried
# {'t': 'untried ', 'n': 'untried'}
# untried
# resources
# {'t': 'resources ', 'n': 'resources'}
# resources
# of
# {'t': 'of ', 'n': 'of'}
# of
# mind.
# {'t': 'mind. ', 'n': 'mind.'}
# mind.
# other
# {'t': 'Other ', 'n': 'other'}
# other
# motives
# {'t': 'motives ', 'n': 'motives'}
# motives
# were
# {'t': 'were ', 'n': 'were'}
# were
# mingled
# {'t': 'mingled ', 'n': 'mingled'}
# mingled
# with
# {'t': 'with ', 'n': 'with'}
# with
# these,
# {'t': 'these, ', 'n': 'these,'}
# these,
# as
# {'t': 'as ', 'n': 'as'}
# as
# the
# {'t': 'the ', 'n': 'the'}
# the
# work
# {'t': 'work ', 'n': 'work'}
# work
# proceeded.
# {'t': 'pro<pb xml:id="F1818_v1_010" n="x"/>ceeded. ', 'n': 'proceeded.'}
# proceeded.
# i
# {'t': 'I ', 'n': 'i'}
# i
# am
# {'t': 'am ', 'n': 'am'}
# am
# by
# {'t': 'by ', 'n': 'by'}
# by
# no
# {'t': 'no ', 'n': 'no'}
# no
# means
# {'t': 'means ', 'n': 'means'}
# means
# indifferent
# {'t': 'indifferent ', 'n': 'indifferent'}
# indifferent
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# manner
# {'t': 'manner ', 'n': 'manner'}
# manner
# in
# {'t': 'in ', 'n': 'in'}
# in
# which
# {'t': 'which ', 'n': 'which'}
# which
# whatever
# {'t': 'whatever ', 'n': 'whatever'}
# whatever
# moral
# {'t': 'moral ', 'n': 'moral'}
# moral
# tendencies
# {'t': 'tendencies ', 'n': 'tendencies'}
# tendencies
# exist
# {'t': 'exist ', 'n': 'exist'}
# exist
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# sentiments
# {'t': 'sentiments ', 'n': 'sentiments'}
# sentiments
# or
# {'t': 'or ', 'n': 'or'}
# or
# characters
# {'t': 'characters ', 'n': 'characters'}
# characters
# it
# {'t': 'it ', 'n': 'it'}
# it
# contains
# {'t': 'contains ', 'n': 'contains'}
# contains
# shall
# {'t': 'shall ', 'n': 'shall'}
# shall
# affect
# {'t': 'affect ', 'n': 'affect'}
# affect
# the
# {'t': 'the ', 'n': 'the'}
# the
# reader;
# {'t': 'reader; ', 'n': 'reader;'}
# reader;
# yet
# {'t': 'yet ', 'n': 'yet'}
# yet
# my
# {'t': 'my ', 'n': 'my'}
# my
# chief
# {'t': 'chief ', 'n': 'chief'}
# chief
# concern
# {'t': 'concern ', 'n': 'concern'}
# concern
# in
# {'t': 'in ', 'n': 'in'}
# in
# this
# {'t': 'this ', 'n': 'this'}
# this
# respect
# {'t': 'respect ', 'n': 'respect'}
# respect
# has
# {'t': 'has ', 'n': 'has'}
# has
# been
# {'t': 'been ', 'n': 'been'}
# been
# limited
# {'t': 'limited ', 'n': 'limited'}
# limited
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# avoiding
# {'t': 'avoiding ', 'n': 'avoiding'}
# avoiding
# the
# {'t': 'the ', 'n': 'the'}
# the
# enervating
# {'t': 'enervating ', 'n': 'enervating'}
# enervating
# effects
# {'t': 'effects ', 'n': 'effects'}
# effects
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# novels
# {'t': 'novels ', 'n': 'novels'}
# novels
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# present
# {'t': 'present ', 'n': 'present'}
# present
# day,
# {'t': 'day, ', 'n': 'day,'}
# day,
# and
# {'t': 'and ', 'n': 'and'}
# and
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# exhibition
# {'t': 'exhibition ', 'n': 'exhibition'}
# exhibition
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# amiableness
# {'t': 'amiableness ', 'n': 'amiableness'}
# amiableness
# of
# {'t': 'of ', 'n': 'of'}
# of
# domestic
# {'t': 'domestic ', 'n': 'domestic'}
# domestic
# affection,
# {'t': 'affection, ', 'n': 'affection,'}
# affection,
# and
# {'t': 'and ', 'n': 'and'}
# and
# the
# {'t': 'the ', 'n': 'the'}
# the
# excellence
# {'t': 'excellence ', 'n': 'excellence'}
# excellence
# of
# {'t': 'of ', 'n': 'of'}
# of
# universal
# {'t': 'universal ', 'n': 'universal'}
# universal
# virtue.
# {'t': 'virtue. ', 'n': 'virtue.'}
# virtue.
# the
# {'t': 'The ', 'n': 'the'}
# the
# opinions
# {'t': 'opinions ', 'n': 'opinions'}
# opinions
# which
# {'t': 'which ', 'n': 'which'}
# which
# naturally
# {'t': 'naturally ', 'n': 'naturally'}
# naturally
# spring
# {'t': 'spring ', 'n': 'spring'}
# spring
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# character
# {'t': 'character ', 'n': 'character'}
# character
# and
# {'t': 'and ', 'n': 'and'}
# and
# situation
# {'t': 'situation ', 'n': 'situation'}
# situation
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# hero
# {'t': 'hero ', 'n': 'hero'}
# hero
# are
# {'t': 'are ', 'n': 'are'}
# are
# by
# {'t': 'by ', 'n': 'by'}
# by
# no
# {'t': 'no ', 'n': 'no'}
# no
# means
# {'t': 'means ', 'n': 'means'}
# means
# to
# {'t': 'to ', 'n': 'to'}
# to
# be
# {'t': 'be ', 'n': 'be'}
# be
# conceived
# {'t': 'conceived ', 'n': 'conceived'}
# conceived
# as
# {'t': 'as ', 'n': 'as'}
# as
# existing
# {'t': 'existing ', 'n': 'existing'}
# existing
# always
# {'t': 'always ', 'n': 'always'}
# always
# in
# {'t': 'in ', 'n': 'in'}
# in
# my
# {'t': 'my ', 'n': 'my'}
# my
# own
# {'t': 'own ', 'n': 'own'}
# own
# conviction;
# {'t': 'conviction; ', 'n': 'conviction;'}
# conviction;
# nor
# {'t': 'nor ', 'n': 'nor'}
# nor
# is
# {'t': 'is ', 'n': 'is'}
# is
# any
# {'t': 'any ', 'n': 'any'}
# any
# inference
# {'t': 'inference ', 'n': 'inference'}
# inference
# justly
# {'t': 'justly ', 'n': 'justly'}
# justly
# to
# {'t': 'to ', 'n': 'to'}
# to
# be
# {'t': 'be ', 'n': 'be'}
# be
# drawn
# {'t': 'drawn ', 'n': 'drawn'}
# drawn
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# following
# {'t': 'following ', 'n': 'following'}
# following
# pages
# {'t': 'pages ', 'n': 'pages'}
# pages
# as
# {'t': 'as ', 'n': 'as'}
# as
# prejudicing
# {'t': 'prejudicing ', 'n': 'prejudicing'}
# prejudicing
# any
# {'t': 'any ', 'n': 'any'}
# any
# philosophical
# {'t': 'philosophical ', 'n': 'philosophical'}
# philosophical
# doctrine
# {'t': 'doctrine ', 'n': 'doctrine'}
# doctrine
# of
# {'t': 'of ', 'n': 'of'}
# of
# whatever
# {'t': 'whatever ', 'n': 'whatever'}
# whatever
# kind.
# {'t': 'kind. ', 'n': 'kind.'}
# kind.
# <p-end/>
# {'t': '<p eID="preface1_p3"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p4"/> ', 'n': '<p-start/>'}
# <p-start/>
# it
# {'t': '<pb xml:id="F1818_v1_011" n="xi"/>It ', 'n': 'it'}
# it
# is
# {'t': 'is ', 'n': 'is'}
# is
# a
# {'t': 'a ', 'n': 'a'}
# a
# subject
# {'t': 'subject ', 'n': 'subject'}
# subject
# also
# {'t': 'also ', 'n': 'also'}
# also
# of
# {'t': 'of ', 'n': 'of'}
# of
# additional
# {'t': 'additional ', 'n': 'additional'}
# additional
# interest
# {'t': 'interest ', 'n': 'interest'}
# interest
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# author,
# {'t': 'author, ', 'n': 'author,'}
# author,
# that
# {'t': 'that ', 'n': 'that'}
# that
# this
# {'t': 'this ', 'n': 'this'}
# this
# story
# {'t': 'story ', 'n': 'story'}
# story
# was
# {'t': 'was ', 'n': 'was'}
# was
# begun
# {'t': 'begun ', 'n': 'begun'}
# begun
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# majestic
# {'t': 'majestic ', 'n': 'majestic'}
# majestic
# region
# {'t': 'region ', 'n': 'region'}
# region
# where
# {'t': 'where ', 'n': 'where'}
# where
# the
# {'t': 'the ', 'n': 'the'}
# the
# scene
# {'t': 'scene ', 'n': 'scene'}
# scene
# is
# {'t': 'is ', 'n': 'is'}
# is
# principally
# {'t': 'principally ', 'n': 'principally'}
# principally
# laid,
# {'t': 'laid, ', 'n': 'laid,'}
# laid,
# and
# {'t': 'and ', 'n': 'and'}
# and
# in
# {'t': 'in ', 'n': 'in'}
# in
# society
# {'t': 'society ', 'n': 'society'}
# society
# which
# {'t': 'which ', 'n': 'which'}
# which
# cannot
# {'t': 'cannot ', 'n': 'cannot'}
# cannot
# cease
# {'t': 'cease ', 'n': 'cease'}
# cease
# to
# {'t': 'to ', 'n': 'to'}
# to
# be
# {'t': 'be ', 'n': 'be'}
# be
# regretted.
# {'t': 'regretted. ', 'n': 'regretted.'}
# regretted.
# i
# {'t': 'I ', 'n': 'i'}
# i
# passed
# {'t': 'passed ', 'n': 'passed'}
# passed
# the
# {'t': 'the ', 'n': 'the'}
# the
# summer
# {'t': 'summer ', 'n': 'summer'}
# summer
# of
# {'t': 'of ', 'n': 'of'}
# of
# 1816
# {'t': '1816 ', 'n': '1816'}
# 1816
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# environs
# {'t': 'environs ', 'n': 'environs'}
# environs
# of
# {'t': 'of ', 'n': 'of'}
# of
# geneva.
# {'t': 'Geneva. ', 'n': 'geneva.'}
# geneva.
# the
# {'t': 'The ', 'n': 'the'}
# the
# season
# {'t': 'season ', 'n': 'season'}
# season
# was
# {'t': 'was ', 'n': 'was'}
# was
# cold
# {'t': 'cold ', 'n': 'cold'}
# cold
# and
# {'t': 'and ', 'n': 'and'}
# and
# rainy,
# {'t': 'rainy, ', 'n': 'rainy,'}
# rainy,
# and
# {'t': 'and ', 'n': 'and'}
# and
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# evenings
# {'t': 'evenings ', 'n': 'evenings'}
# evenings
# we
# {'t': 'we ', 'n': 'we'}
# we
# crowded
# {'t': 'crowded ', 'n': 'crowded'}
# crowded
# around
# {'t': 'around ', 'n': 'around'}
# around
# a
# {'t': 'a ', 'n': 'a'}
# a
# blazing
# {'t': 'blazing ', 'n': 'blazing'}
# blazing
# wood
# {'t': 'wood ', 'n': 'wood'}
# wood
# fire,
# {'t': 'fire, ', 'n': 'fire,'}
# fire,
# and
# {'t': 'and ', 'n': 'and'}
# and
# occasionally
# {'t': 'occasionally ', 'n': 'occasionally'}
# occasionally
# amused
# {'t': 'amused ', 'n': 'amused'}
# amused
# ourselves
# {'t': 'ourselves ', 'n': 'ourselves'}
# ourselves
# with
# {'t': 'with ', 'n': 'with'}
# with
# some
# {'t': 'some ', 'n': 'some'}
# some
# german
# {'t': 'German ', 'n': 'german'}
# german
# stories
# {'t': 'stories ', 'n': 'stories'}
# stories
# of
# {'t': 'of ', 'n': 'of'}
# of
# ghosts,
# {'t': 'ghosts, ', 'n': 'ghosts,'}
# ghosts,
# which
# {'t': 'which ', 'n': 'which'}
# which
# happened
# {'t': 'happened ', 'n': 'happened'}
# happened
# to
# {'t': 'to ', 'n': 'to'}
# to
# fall
# {'t': 'fall ', 'n': 'fall'}
# fall
# into
# {'t': 'into ', 'n': 'into'}
# into
# our
# {'t': 'our ', 'n': 'our'}
# our
# hands.
# {'t': 'hands. ', 'n': 'hands.'}
# hands.
# these
# {'t': 'These ', 'n': 'these'}
# these
# tales
# {'t': 'tales ', 'n': 'tales'}
# tales
# excited
# {'t': 'excited ', 'n': 'excited'}
# excited
# in
# {'t': 'in ', 'n': 'in'}
# in
# us
# {'t': 'us ', 'n': 'us'}
# us
# a
# {'t': 'a ', 'n': 'a'}
# a
# playful
# {'t': 'playful ', 'n': 'playful'}
# playful
# desire
# {'t': 'desire ', 'n': 'desire'}
# desire
# of
# {'t': 'of ', 'n': 'of'}
# of
# imitation.
# {'t': 'imitation. ', 'n': 'imitation.'}
# imitation.
# two
# {'t': 'Two ', 'n': 'two'}
# two
# other
# {'t': 'other ', 'n': 'other'}
# other
# friends
# {'t': 'friends ', 'n': 'friends'}
# friends
# (a
# {'t': '(a ', 'n': '(a'}
# (a
# tale
# {'t': 'tale ', 'n': 'tale'}
# tale
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# pen
# {'t': 'pen ', 'n': 'pen'}
# pen
# of
# {'t': 'of ', 'n': 'of'}
# of
# one
# {'t': 'one ', 'n': 'one'}
# one
# of
# {'t': 'of ', 'n': 'of'}
# of
# whom
# {'t': 'whom ', 'n': 'whom'}
# whom
# would
# {'t': 'would ', 'n': 'would'}
# would
# be
# {'t': 'be ', 'n': 'be'}
# be
# far
# {'t': 'far ', 'n': 'far'}
# far
# more
# {'t': 'more ', 'n': 'more'}
# more
# acceptable
# {'t': 'acceptable ', 'n': 'acceptable'}
# acceptable
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# public
# {'t': 'public ', 'n': 'public'}
# public
# than
# {'t': 'than ', 'n': 'than'}
# than
# any
# {'t': 'any ', 'n': 'any'}
# any
# thing
# {'t': 'thing ', 'n': 'thing'}
# thing
# i
# {'t': 'I ', 'n': 'i'}
# i
# can
# {'t': 'can ', 'n': 'can'}
# can
# ever
# {'t': 'ever ', 'n': 'ever'}
# ever
# hope
# {'t': 'hope ', 'n': 'hope'}
# hope
# to
# {'t': 'to ', 'n': 'to'}
# to
# produce)
# {'t': 'produce) ', 'n': 'produce)'}
# produce)
# and
# {'t': 'and ', 'n': 'and'}
# and
# myself
# {'t': '<pb xml:id="F1818_v1_012" n="xii"/>myself ', 'n': 'myself'}
# myself
# agreed
# {'t': 'agreed ', 'n': 'agreed'}
# agreed
# to
# {'t': 'to ', 'n': 'to'}
# to
# write
# {'t': 'write ', 'n': 'write'}
# write
# each
# {'t': 'each ', 'n': 'each'}
# each
# a
# {'t': 'a ', 'n': 'a'}
# a
# story,
# {'t': 'story, ', 'n': 'story,'}
# story,
# founded
# {'t': 'founded ', 'n': 'founded'}
# founded
# on
# {'t': 'on ', 'n': 'on'}
# on
# some
# {'t': 'some ', 'n': 'some'}
# some
# supernatural
# {'t': 'supernatural ', 'n': 'supernatural'}
# supernatural
# occurrence.
# {'t': 'occurrence. ', 'n': 'occurrence.'}
# occurrence.
# <p-end/>
# {'t': '<p eID="preface1_p4"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p5"/> ', 'n': '<p-start/>'}
# <p-start/>
# the
# {'t': 'The ', 'n': 'the'}
# the
# weather,
# {'t': 'weather, ', 'n': 'weather,'}
# weather,
# however,
# {'t': 'however, ', 'n': 'however,'}
# however,
# suddenly
# {'t': 'suddenly ', 'n': 'suddenly'}
# suddenly
# became
# {'t': 'became ', 'n': 'became'}
# became
# serene;
# {'t': 'serene; ', 'n': 'serene;'}
# serene;
# and
# {'t': 'and ', 'n': 'and'}
# and
# my
# {'t': 'my ', 'n': 'my'}
# my
# two
# {'t': 'two ', 'n': 'two'}
# two
# friends
# {'t': 'friends ', 'n': 'friends'}
# friends
# left
# {'t': 'left ', 'n': 'left'}
# left
# me
# {'t': 'me ', 'n': 'me'}
# me
# on
# {'t': 'on ', 'n': 'on'}
# on
# a
# {'t': 'a ', 'n': 'a'}
# a
# journey
# {'t': 'journey ', 'n': 'journey'}
# journey
# among
# {'t': 'among ', 'n': 'among'}
# among
# the
# {'t': 'the ', 'n': 'the'}
# the
# alps,
# {'t': 'Alps, ', 'n': 'alps,'}
# alps,
# and
# {'t': 'and ', 'n': 'and'}
# and
# lost,
# {'t': 'lost, ', 'n': 'lost,'}
# lost,
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# magnificent
# {'t': 'magnificent ', 'n': 'magnificent'}
# magnificent
# scenes
# {'t': 'scenes ', 'n': 'scenes'}
# scenes
# which
# {'t': 'which ', 'n': 'which'}
# which
# they
# {'t': 'they ', 'n': 'they'}
# they
# present,
# {'t': 'present, ', 'n': 'present,'}
# present,
# all
# {'t': 'all ', 'n': 'all'}
# all
# memory
# {'t': 'memory ', 'n': 'memory'}
# memory
# of
# {'t': 'of ', 'n': 'of'}
# of
# their
# {'t': 'their ', 'n': 'their'}
# their
# ghostly
# {'t': 'ghostly ', 'n': 'ghostly'}
# ghostly
# visions.
# {'t': 'visions. ', 'n': 'visions.'}
# visions.
# the
# {'t': 'The ', 'n': 'the'}
# the
# following
# {'t': 'following ', 'n': 'following'}
# following
# tale
# {'t': 'tale ', 'n': 'tale'}
# tale
# is
# {'t': 'is ', 'n': 'is'}
# is
# the
# {'t': 'the ', 'n': 'the'}
# the
# only
# {'t': 'only ', 'n': 'only'}
# only
# one
# {'t': 'one ', 'n': 'one'}
# one
# which
# {'t': 'which ', 'n': 'which'}
# which
# has
# {'t': 'has ', 'n': 'has'}
# has
# been
# {'t': 'been ', 'n': 'been'}
# been
# completed.
# {'t': 'completed. ', 'n': 'completed.'}
# completed.
# <p-end/>
# {'t': '<p eID="preface1_p5"/> ', 'n': '<p-end/>'}
# <p-end/>
#
# {'t': '<milestone unit="preface" type="end" n="1"/> ', 'n': ''}
#
#
# {'t': ' ', 'n': ''}
#
#
# {'t': ' ', 'n': ''}
#
#
# {'t': '<milestone unit="volume" n="1"/> ', 'n': ''}
#
#
# {'t': '<milestone unit="frontmatter" type="start" n="1"/> ', 'n': ''}
#
#
# {'t': '<milestone unit="frontmatter" type="end" n="1"/> ', 'n': ''}
#
#
# {'t': '<milestone unit="preface" type="start" n="1"/> ', 'n': ''}
#
#
# {'t': '<pb xml:id="F1818_v1_007" n="viii"/> ', 'n': ''}
#
# preface.
# {'t': '<head>PREFACE.</head> ', 'n': 'preface.'}
# preface.
# <p-start/>
# {'t': '<p sID="preface1_p1"/> ', 'n': '<p-start/>'}
# <p-start/>
# t<hi>he</hi>
# {'t': 'T<hi sID="preface1_p1_hi1"/>HE<hi eID="preface1_p1_hi1"/> ', 'n': 't<hi>he</hi>'}
# t<hi>he</hi>
# event
# {'t': 'event ', 'n': 'event'}
# event
# on
# {'t': 'on ', 'n': 'on'}
# on
# which
# {'t': 'which ', 'n': 'which'}
# which
# this
# {'t': 'this ', 'n': 'this'}
# this
# fiction
# {'t': 'fiction ', 'n': 'fiction'}
# fiction
# is
# {'t': 'is ', 'n': 'is'}
# is
# founded
# {'t': 'founded ', 'n': 'founded'}
# founded
# has
# {'t': 'has ', 'n': 'has'}
# has
# been
# {'t': 'been ', 'n': 'been'}
# been
# supposed,
# {'t': 'supposed, ', 'n': 'supposed,'}
# supposed,
# by
# {'t': 'by ', 'n': 'by'}
# by
# dr.
# {'t': 'Dr. ', 'n': 'dr.'}
# dr.
# darwin,
# {'t': 'Darwin, ', 'n': 'darwin,'}
# darwin,
# and
# {'t': 'and ', 'n': 'and'}
# and
# some
# {'t': 'some ', 'n': 'some'}
# some
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# physiological
# {'t': 'physiological ', 'n': 'physiological'}
# physiological
# writers
# {'t': 'writers ', 'n': 'writers'}
# writers
# of
# {'t': 'of ', 'n': 'of'}
# of
# germany,
# {'t': 'Germany, ', 'n': 'germany,'}
# germany,
# as
# {'t': 'as ', 'n': 'as'}
# as
# not
# {'t': 'not ', 'n': 'not'}
# not
# of
# {'t': 'of ', 'n': 'of'}
# of
# impossible
# {'t': 'impossible ', 'n': 'impossible'}
# impossible
# occurrence.
# {'t': 'occurrence. ', 'n': 'occurrence.'}
# occurrence.
# i
# {'t': 'I ', 'n': 'i'}
# i
# shall
# {'t': 'shall ', 'n': 'shall'}
# shall
# not
# {'t': 'not ', 'n': 'not'}
# not
# be
# {'t': 'be ', 'n': 'be'}
# be
# supposed
# {'t': 'supposed ', 'n': 'supposed'}
# supposed
# as
# {'t': 'as ', 'n': 'as'}
# as
# according
# {'t': 'according ', 'n': 'according'}
# according
# the
# {'t': 'the ', 'n': 'the'}
# the
# remotest
# {'t': 'remotest ', 'n': 'remotest'}
# remotest
# degree
# {'t': 'degree ', 'n': 'degree'}
# degree
# of
# {'t': 'of ', 'n': 'of'}
# of
# serious
# {'t': 'serious ', 'n': 'serious'}
# serious
# faith
# {'t': 'faith ', 'n': 'faith'}
# faith
# to
# {'t': 'to ', 'n': 'to'}
# to
# such
# {'t': 'such ', 'n': 'such'}
# such
# an
# {'t': 'an ', 'n': 'an'}
# an
# imagination;
# {'t': 'imagination; ', 'n': 'imagination;'}
# imagination;
# yet,
# {'t': 'yet, ', 'n': 'yet,'}
# yet,
# in
# {'t': 'in ', 'n': 'in'}
# in
# assuming
# {'t': 'assuming ', 'n': 'assuming'}
# assuming
# it
# {'t': 'it ', 'n': 'it'}
# it
# as
# {'t': 'as ', 'n': 'as'}
# as
# the
# {'t': 'the ', 'n': 'the'}
# the
# basis
# {'t': 'basis ', 'n': 'basis'}
# basis
# of
# {'t': 'of ', 'n': 'of'}
# of
# a
# {'t': 'a ', 'n': 'a'}
# a
# work
# {'t': 'work ', 'n': 'work'}
# work
# of
# {'t': 'of ', 'n': 'of'}
# of
# fancy,
# {'t': 'fancy, ', 'n': 'fancy,'}
# fancy,
# i
# {'t': 'I ', 'n': 'i'}
# i
# have
# {'t': 'have ', 'n': 'have'}
# have
# not
# {'t': 'not ', 'n': 'not'}
# not
# considered
# {'t': 'considered ', 'n': 'considered'}
# considered
# myself
# {'t': 'myself ', 'n': 'myself'}
# myself
# as
# {'t': 'as ', 'n': 'as'}
# as
# merely
# {'t': 'merely ', 'n': 'merely'}
# merely
# weaving
# {'t': 'weaving ', 'n': 'weaving'}
# weaving
# a
# {'t': 'a ', 'n': 'a'}
# a
# series
# {'t': 'series ', 'n': 'series'}
# series
# of
# {'t': 'of ', 'n': 'of'}
# of
# supernatural
# {'t': 'supernatural ', 'n': 'supernatural'}
# supernatural
# terrors.
# {'t': 'terrors. ', 'n': 'terrors.'}
# terrors.
# the
# {'t': 'The ', 'n': 'the'}
# the
# event
# {'t': 'event ', 'n': 'event'}
# event
# on
# {'t': 'on ', 'n': 'on'}
# on
# which
# {'t': '<pb xml:id="F1818_v1_008" n="viii"/>which ', 'n': 'which'}
# which
# the
# {'t': 'the ', 'n': 'the'}
# the
# interest
# {'t': 'interest ', 'n': 'interest'}
# interest
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# story
# {'t': 'story ', 'n': 'story'}
# story
# depends
# {'t': 'depends ', 'n': 'depends'}
# depends
# is
# {'t': 'is ', 'n': 'is'}
# is
# exempt
# {'t': 'exempt ', 'n': 'exempt'}
# exempt
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# disadvantages
# {'t': 'disadvantages ', 'n': 'disadvantages'}
# disadvantages
# of
# {'t': 'of ', 'n': 'of'}
# of
# a
# {'t': 'a ', 'n': 'a'}
# a
# mere
# {'t': 'mere ', 'n': 'mere'}
# mere
# tale
# {'t': 'tale ', 'n': 'tale'}
# tale
# of
# {'t': 'of ', 'n': 'of'}
# of
# spectres
# {'t': 'spectres ', 'n': 'spectres'}
# spectres
# or
# {'t': 'or ', 'n': 'or'}
# or
# enchantment.
# {'t': 'enchantment. ', 'n': 'enchantment.'}
# enchantment.
# it
# {'t': 'It ', 'n': 'it'}
# it
# was
# {'t': 'was ', 'n': 'was'}
# was
# recommended
# {'t': 'recommended ', 'n': 'recommended'}
# recommended
# by
# {'t': 'by ', 'n': 'by'}
# by
# the
# {'t': 'the ', 'n': 'the'}
# the
# novelty
# {'t': 'novelty ', 'n': 'novelty'}
# novelty
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# situations
# {'t': 'situations ', 'n': 'situations'}
# situations
# which
# {'t': 'which ', 'n': 'which'}
# which
# it
# {'t': 'it ', 'n': 'it'}
# it
# developes;
# {'t': 'developes; ', 'n': 'developes;'}
# developes;
# and,
# {'t': 'and, ', 'n': 'and,'}
# and,
# however
# {'t': 'however ', 'n': 'however'}
# however
# impossible
# {'t': 'impossible ', 'n': 'impossible'}
# impossible
# as
# {'t': 'as ', 'n': 'as'}
# as
# a
# {'t': 'a ', 'n': 'a'}
# a
# physical
# {'t': 'physical ', 'n': 'physical'}
# physical
# fact,
# {'t': 'fact, ', 'n': 'fact,'}
# fact,
# affords
# {'t': 'affords ', 'n': 'affords'}
# affords
# a
# {'t': 'a ', 'n': 'a'}
# a
# point
# {'t': 'point ', 'n': 'point'}
# point
# of
# {'t': 'of ', 'n': 'of'}
# of
# view
# {'t': 'view ', 'n': 'view'}
# view
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# imagination
# {'t': 'imagination ', 'n': 'imagination'}
# imagination
# for
# {'t': 'for ', 'n': 'for'}
# for
# the
# {'t': 'the ', 'n': 'the'}
# the
# delineating
# {'t': 'delineating ', 'n': 'delineating'}
# delineating
# of
# {'t': 'of ', 'n': 'of'}
# of
# human
# {'t': 'human ', 'n': 'human'}
# human
# passions
# {'t': 'passions ', 'n': 'passions'}
# passions
# more
# {'t': 'more ', 'n': 'more'}
# more
# comprehensive
# {'t': 'comprehensive ', 'n': 'comprehensive'}
# comprehensive
# and
# {'t': 'and ', 'n': 'and'}
# and
# commanding
# {'t': 'commanding ', 'n': 'commanding'}
# commanding
# than
# {'t': 'than ', 'n': 'than'}
# than
# any
# {'t': 'any ', 'n': 'any'}
# any
# which
# {'t': 'which ', 'n': 'which'}
# which
# the
# {'t': 'the ', 'n': 'the'}
# the
# ordinary
# {'t': 'ordinary ', 'n': 'ordinary'}
# ordinary
# relations
# {'t': 'relations ', 'n': 'relations'}
# relations
# of
# {'t': 'of ', 'n': 'of'}
# of
# existing
# {'t': 'existing ', 'n': 'existing'}
# existing
# events
# {'t': 'events ', 'n': 'events'}
# events
# can
# {'t': 'can ', 'n': 'can'}
# can
# yield.
# {'t': 'yield. ', 'n': 'yield.'}
# yield.
# <p-end/>
# {'t': '<p eID="preface1_p1"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p2"/> ', 'n': '<p-start/>'}
# <p-start/>
# i
# {'t': 'I ', 'n': 'i'}
# i
# have
# {'t': 'have ', 'n': 'have'}
# have
# thus
# {'t': 'thus ', 'n': 'thus'}
# thus
# endeavoured
# {'t': 'endeavoured ', 'n': 'endeavoured'}
# endeavoured
# to
# {'t': 'to ', 'n': 'to'}
# to
# preserve
# {'t': 'preserve ', 'n': 'preserve'}
# preserve
# the
# {'t': 'the ', 'n': 'the'}
# the
# truth
# {'t': 'truth ', 'n': 'truth'}
# truth
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# elementary
# {'t': 'elementary ', 'n': 'elementary'}
# elementary
# principles
# {'t': 'principles ', 'n': 'principles'}
# principles
# of
# {'t': 'of ', 'n': 'of'}
# of
# human
# {'t': 'human ', 'n': 'human'}
# human
# nature,
# {'t': 'nature, ', 'n': 'nature,'}
# nature,
# while
# {'t': 'while ', 'n': 'while'}
# while
# i
# {'t': 'I ', 'n': 'i'}
# i
# have
# {'t': 'have ', 'n': 'have'}
# have
# not
# {'t': 'not ', 'n': 'not'}
# not
# scrupled
# {'t': 'scrupled ', 'n': 'scrupled'}
# scrupled
# to
# {'t': 'to ', 'n': 'to'}
# to
# innovate
# {'t': 'innovate ', 'n': 'innovate'}
# innovate
# upon
# {'t': 'upon ', 'n': 'upon'}
# upon
# their
# {'t': 'their ', 'n': 'their'}
# their
# combinations.
# {'t': 'combinations. ', 'n': 'combinations.'}
# combinations.
# the
# {'t': 'The ', 'n': 'the'}
# the
# <hi>iliad</hi>,
# {'t': '<hi sID="preface1_p2_hi1"/>Iliad<hi eID="preface1_p2_hi1"/>, ', 'n': '<hi>iliad</hi>,'}
# <hi>iliad</hi>,
# the
# {'t': 'the ', 'n': 'the'}
# the
# tragic
# {'t': 'tragic ', 'n': 'tragic'}
# tragic
# poetry
# {'t': 'poetry ', 'n': 'poetry'}
# poetry
# of
# {'t': 'of ', 'n': 'of'}
# of
# greece,—shakespeare,
# {'t': 'Greece,—Shakespeare, ', 'n': 'greece,—shakespeare,'}
# greece,—shakespeare,
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# <hi>tempest</hi>
# {'t': '<hi sID="preface1_p2_hi2"/>Tempest<hi eID="preface1_p2_hi2"/> ', 'n': '<hi>tempest</hi>'}
# <hi>tempest</hi>
# and
# {'t': 'and ', 'n': 'and'}
# and
# <hi>midsummer
# {'t': '<hi sID="preface1_p2_hi3"/>Mid<pb xml:id="F1818_v1_009" n="ix"/>summer ', 'n': '<hi>midsummer'}
# <hi>midsummer
# night’s
# {'t': 'Night’s ', 'n': 'night’s'}
# night’s
# dream</hi>,—and
# {'t': 'Dream<hi eID="preface1_p2_hi3"/>,—and ', 'n': 'dream</hi>,—and'}
# dream</hi>,—and
# most
# {'t': 'most ', 'n': 'most'}
# most
# especially
# {'t': 'especially ', 'n': 'especially'}
# especially
# milton,
# {'t': 'Milton, ', 'n': 'milton,'}
# milton,
# in
# {'t': 'in ', 'n': 'in'}
# in
# <hi>paradise
# {'t': '<hi sID="preface1_p2_hi4"/>Paradise ', 'n': '<hi>paradise'}
# <hi>paradise
# lost</hi>,
# {'t': 'Lost<hi eID="preface1_p2_hi4"/>, ', 'n': 'lost</hi>,'}
# lost</hi>,
# conform
# {'t': 'conform ', 'n': 'conform'}
# conform
# to
# {'t': 'to ', 'n': 'to'}
# to
# this
# {'t': 'this ', 'n': 'this'}
# this
# rule;
# {'t': 'rule; ', 'n': 'rule;'}
# rule;
# and
# {'t': 'and ', 'n': 'and'}
# and
# the
# {'t': 'the ', 'n': 'the'}
# the
# most
# {'t': 'most ', 'n': 'most'}
# most
# humble
# {'t': 'humble ', 'n': 'humble'}
# humble
# novelist,
# {'t': 'novelist, ', 'n': 'novelist,'}
# novelist,
# who
# {'t': 'who ', 'n': 'who'}
# who
# seeks
# {'t': 'seeks ', 'n': 'seeks'}
# seeks
# to
# {'t': 'to ', 'n': 'to'}
# to
# confer
# {'t': 'confer ', 'n': 'confer'}
# confer
# or
# {'t': 'or ', 'n': 'or'}
# or
# receive
# {'t': 'receive ', 'n': 'receive'}
# receive
# amusement
# {'t': 'amusement ', 'n': 'amusement'}
# amusement
# from
# {'t': 'from ', 'n': 'from'}
# from
# his
# {'t': 'his ', 'n': 'his'}
# his
# labours,
# {'t': 'labours, ', 'n': 'labours,'}
# labours,
# may,
# {'t': 'may, ', 'n': 'may,'}
# may,
# without
# {'t': 'without ', 'n': 'without'}
# without
# presumption,
# {'t': 'presumption, ', 'n': 'presumption,'}
# presumption,
# apply
# {'t': 'apply ', 'n': 'apply'}
# apply
# to
# {'t': 'to ', 'n': 'to'}
# to
# prose
# {'t': 'prose ', 'n': 'prose'}
# prose
# fiction
# {'t': 'fiction ', 'n': 'fiction'}
# fiction
# a
# {'t': 'a ', 'n': 'a'}
# a
# licence,
# {'t': 'licence, ', 'n': 'licence,'}
# licence,
# or
# {'t': 'or ', 'n': 'or'}
# or
# rather
# {'t': 'rather ', 'n': 'rather'}
# rather
# a
# {'t': 'a ', 'n': 'a'}
# a
# rule,
# {'t': 'rule, ', 'n': 'rule,'}
# rule,
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# adoption
# {'t': 'adoption ', 'n': 'adoption'}
# adoption
# of
# {'t': 'of ', 'n': 'of'}
# of
# which
# {'t': 'which ', 'n': 'which'}
# which
# so
# {'t': 'so ', 'n': 'so'}
# so
# many
# {'t': 'many ', 'n': 'many'}
# many
# exquisite
# {'t': 'exquisite ', 'n': 'exquisite'}
# exquisite
# combinations
# {'t': 'combinations ', 'n': 'combinations'}
# combinations
# of
# {'t': 'of ', 'n': 'of'}
# of
# human
# {'t': 'human ', 'n': 'human'}
# human
# feeling
# {'t': 'feeling ', 'n': 'feeling'}
# feeling
# have
# {'t': 'have ', 'n': 'have'}
# have
# resulted
# {'t': 'resulted ', 'n': 'resulted'}
# resulted
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# highest
# {'t': 'highest ', 'n': 'highest'}
# highest
# specimens
# {'t': 'specimens ', 'n': 'specimens'}
# specimens
# of
# {'t': 'of ', 'n': 'of'}
# of
# poetry.
# {'t': 'poetry. ', 'n': 'poetry.'}
# poetry.
# <p-end/>
# {'t': '<p eID="preface1_p2"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p3"/> ', 'n': '<p-start/>'}
# <p-start/>
# the
# {'t': 'The ', 'n': 'the'}
# the
# circumstance
# {'t': 'circumstance ', 'n': 'circumstance'}
# circumstance
# on
# {'t': 'on ', 'n': 'on'}
# on
# which
# {'t': 'which ', 'n': 'which'}
# which
# my
# {'t': 'my ', 'n': 'my'}
# my
# story
# {'t': 'story ', 'n': 'story'}
# story
# rests
# {'t': 'rests ', 'n': 'rests'}
# rests
# was
# {'t': 'was ', 'n': 'was'}
# was
# suggested
# {'t': 'suggested ', 'n': 'suggested'}
# suggested
# in
# {'t': 'in ', 'n': 'in'}
# in
# casual
# {'t': 'casual ', 'n': 'casual'}
# casual
# conversation.
# {'t': 'conversation. ', 'n': 'conversation.'}
# conversation.
# it
# {'t': 'It ', 'n': 'it'}
# it
# was
# {'t': 'was ', 'n': 'was'}
# was
# commenced
# {'t': 'commenced ', 'n': 'commenced'}
# commenced
# partly
# {'t': 'partly ', 'n': 'partly'}
# partly
# as
# {'t': 'as ', 'n': 'as'}
# as
# a
# {'t': 'a ', 'n': 'a'}
# a
# source
# {'t': 'source ', 'n': 'source'}
# source
# of
# {'t': 'of ', 'n': 'of'}
# of
# amusement,
# {'t': 'amusement, ', 'n': 'amusement,'}
# amusement,
# and
# {'t': 'and ', 'n': 'and'}
# and
# partly
# {'t': 'partly ', 'n': 'partly'}
# partly
# as
# {'t': 'as ', 'n': 'as'}
# as
# an
# {'t': 'an ', 'n': 'an'}
# an
# expedient
# {'t': 'expedient ', 'n': 'expedient'}
# expedient
# for
# {'t': 'for ', 'n': 'for'}
# for
# exercising
# {'t': 'exercising ', 'n': 'exercising'}
# exercising
# any
# {'t': 'any ', 'n': 'any'}
# any
# untried
# {'t': 'untried ', 'n': 'untried'}
# untried
# resources
# {'t': 'resources ', 'n': 'resources'}
# resources
# of
# {'t': 'of ', 'n': 'of'}
# of
# mind.
# {'t': 'mind. ', 'n': 'mind.'}
# mind.
# other
# {'t': 'Other ', 'n': 'other'}
# other
# motives
# {'t': 'motives ', 'n': 'motives'}
# motives
# were
# {'t': 'were ', 'n': 'were'}
# were
# mingled
# {'t': 'mingled ', 'n': 'mingled'}
# mingled
# with
# {'t': 'with ', 'n': 'with'}
# with
# these,
# {'t': 'these, ', 'n': 'these,'}
# these,
# as
# {'t': 'as ', 'n': 'as'}
# as
# the
# {'t': 'the ', 'n': 'the'}
# the
# work
# {'t': 'work ', 'n': 'work'}
# work
# proceeded.
# {'t': 'pro<pb xml:id="F1818_v1_010" n="x"/>ceeded. ', 'n': 'proceeded.'}
# proceeded.
# i
# {'t': 'I ', 'n': 'i'}
# i
# am
# {'t': 'am ', 'n': 'am'}
# am
# by
# {'t': 'by ', 'n': 'by'}
# by
# no
# {'t': 'no ', 'n': 'no'}
# no
# means
# {'t': 'means ', 'n': 'means'}
# means
# indifferent
# {'t': 'indifferent ', 'n': 'indifferent'}
# indifferent
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# manner
# {'t': 'manner ', 'n': 'manner'}
# manner
# in
# {'t': 'in ', 'n': 'in'}
# in
# which
# {'t': 'which ', 'n': 'which'}
# which
# whatever
# {'t': 'whatever ', 'n': 'whatever'}
# whatever
# moral
# {'t': 'moral ', 'n': 'moral'}
# moral
# tendencies
# {'t': 'tendencies ', 'n': 'tendencies'}
# tendencies
# exist
# {'t': 'exist ', 'n': 'exist'}
# exist
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# sentiments
# {'t': 'sentiments ', 'n': 'sentiments'}
# sentiments
# or
# {'t': 'or ', 'n': 'or'}
# or
# characters
# {'t': 'characters ', 'n': 'characters'}
# characters
# it
# {'t': 'it ', 'n': 'it'}
# it
# contains
# {'t': 'contains ', 'n': 'contains'}
# contains
# shall
# {'t': 'shall ', 'n': 'shall'}
# shall
# affect
# {'t': 'affect ', 'n': 'affect'}
# affect
# the
# {'t': 'the ', 'n': 'the'}
# the
# reader;
# {'t': 'reader; ', 'n': 'reader;'}
# reader;
# yet
# {'t': 'yet ', 'n': 'yet'}
# yet
# my
# {'t': 'my ', 'n': 'my'}
# my
# chief
# {'t': 'chief ', 'n': 'chief'}
# chief
# concern
# {'t': 'concern ', 'n': 'concern'}
# concern
# in
# {'t': 'in ', 'n': 'in'}
# in
# this
# {'t': 'this ', 'n': 'this'}
# this
# respect
# {'t': 'respect ', 'n': 'respect'}
# respect
# has
# {'t': 'has ', 'n': 'has'}
# has
# been
# {'t': 'been ', 'n': 'been'}
# been
# limited
# {'t': 'limited ', 'n': 'limited'}
# limited
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# avoiding
# {'t': 'avoiding ', 'n': 'avoiding'}
# avoiding
# the
# {'t': 'the ', 'n': 'the'}
# the
# enervating
# {'t': 'enervating ', 'n': 'enervating'}
# enervating
# effects
# {'t': 'effects ', 'n': 'effects'}
# effects
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# novels
# {'t': 'novels ', 'n': 'novels'}
# novels
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# present
# {'t': 'present ', 'n': 'present'}
# present
# day,
# {'t': 'day, ', 'n': 'day,'}
# day,
# and
# {'t': 'and ', 'n': 'and'}
# and
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# exhibition
# {'t': 'exhibition ', 'n': 'exhibition'}
# exhibition
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# amiableness
# {'t': 'amiableness ', 'n': 'amiableness'}
# amiableness
# of
# {'t': 'of ', 'n': 'of'}
# of
# domestic
# {'t': 'domestic ', 'n': 'domestic'}
# domestic
# affection,
# {'t': 'affection, ', 'n': 'affection,'}
# affection,
# and
# {'t': 'and ', 'n': 'and'}
# and
# the
# {'t': 'the ', 'n': 'the'}
# the
# excellence
# {'t': 'excellence ', 'n': 'excellence'}
# excellence
# of
# {'t': 'of ', 'n': 'of'}
# of
# universal
# {'t': 'universal ', 'n': 'universal'}
# universal
# virtue.
# {'t': 'virtue. ', 'n': 'virtue.'}
# virtue.
# the
# {'t': 'The ', 'n': 'the'}
# the
# opinions
# {'t': 'opinions ', 'n': 'opinions'}
# opinions
# which
# {'t': 'which ', 'n': 'which'}
# which
# naturally
# {'t': 'naturally ', 'n': 'naturally'}
# naturally
# spring
# {'t': 'spring ', 'n': 'spring'}
# spring
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# character
# {'t': 'character ', 'n': 'character'}
# character
# and
# {'t': 'and ', 'n': 'and'}
# and
# situation
# {'t': 'situation ', 'n': 'situation'}
# situation
# of
# {'t': 'of ', 'n': 'of'}
# of
# the
# {'t': 'the ', 'n': 'the'}
# the
# hero
# {'t': 'hero ', 'n': 'hero'}
# hero
# are
# {'t': 'are ', 'n': 'are'}
# are
# by
# {'t': 'by ', 'n': 'by'}
# by
# no
# {'t': 'no ', 'n': 'no'}
# no
# means
# {'t': 'means ', 'n': 'means'}
# means
# to
# {'t': 'to ', 'n': 'to'}
# to
# be
# {'t': 'be ', 'n': 'be'}
# be
# conceived
# {'t': 'conceived ', 'n': 'conceived'}
# conceived
# as
# {'t': 'as ', 'n': 'as'}
# as
# existing
# {'t': 'existing ', 'n': 'existing'}
# existing
# always
# {'t': 'always ', 'n': 'always'}
# always
# in
# {'t': 'in ', 'n': 'in'}
# in
# my
# {'t': 'my ', 'n': 'my'}
# my
# own
# {'t': 'own ', 'n': 'own'}
# own
# conviction;
# {'t': 'conviction; ', 'n': 'conviction;'}
# conviction;
# nor
# {'t': 'nor ', 'n': 'nor'}
# nor
# is
# {'t': 'is ', 'n': 'is'}
# is
# any
# {'t': 'any ', 'n': 'any'}
# any
# inference
# {'t': 'inference ', 'n': 'inference'}
# inference
# justly
# {'t': 'justly ', 'n': 'justly'}
# justly
# to
# {'t': 'to ', 'n': 'to'}
# to
# be
# {'t': 'be ', 'n': 'be'}
# be
# drawn
# {'t': 'drawn ', 'n': 'drawn'}
# drawn
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# following
# {'t': 'following ', 'n': 'following'}
# following
# pages
# {'t': 'pages ', 'n': 'pages'}
# pages
# as
# {'t': 'as ', 'n': 'as'}
# as
# prejudicing
# {'t': 'prejudicing ', 'n': 'prejudicing'}
# prejudicing
# any
# {'t': 'any ', 'n': 'any'}
# any
# philosophical
# {'t': 'philosophical ', 'n': 'philosophical'}
# philosophical
# doctrine
# {'t': 'doctrine ', 'n': 'doctrine'}
# doctrine
# of
# {'t': 'of ', 'n': 'of'}
# of
# whatever
# {'t': 'whatever ', 'n': 'whatever'}
# whatever
# kind.
# {'t': 'kind. ', 'n': 'kind.'}
# kind.
# <p-end/>
# {'t': '<p eID="preface1_p3"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p4"/> ', 'n': '<p-start/>'}
# <p-start/>
# it
# {'t': '<pb xml:id="F1818_v1_011" n="xi"/>It ', 'n': 'it'}
# it
# is
# {'t': 'is ', 'n': 'is'}
# is
# a
# {'t': 'a ', 'n': 'a'}
# a
# subject
# {'t': 'subject ', 'n': 'subject'}
# subject
# also
# {'t': 'also ', 'n': 'also'}
# also
# of
# {'t': 'of ', 'n': 'of'}
# of
# additional
# {'t': 'additional ', 'n': 'additional'}
# additional
# interest
# {'t': 'interest ', 'n': 'interest'}
# interest
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# author,
# {'t': 'author, ', 'n': 'author,'}
# author,
# that
# {'t': 'that ', 'n': 'that'}
# that
# this
# {'t': 'this ', 'n': 'this'}
# this
# story
# {'t': 'story ', 'n': 'story'}
# story
# was
# {'t': 'was ', 'n': 'was'}
# was
# begun
# {'t': 'begun ', 'n': 'begun'}
# begun
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# majestic
# {'t': 'majestic ', 'n': 'majestic'}
# majestic
# region
# {'t': 'region ', 'n': 'region'}
# region
# where
# {'t': 'where ', 'n': 'where'}
# where
# the
# {'t': 'the ', 'n': 'the'}
# the
# scene
# {'t': 'scene ', 'n': 'scene'}
# scene
# is
# {'t': 'is ', 'n': 'is'}
# is
# principally
# {'t': 'principally ', 'n': 'principally'}
# principally
# laid,
# {'t': 'laid, ', 'n': 'laid,'}
# laid,
# and
# {'t': 'and ', 'n': 'and'}
# and
# in
# {'t': 'in ', 'n': 'in'}
# in
# society
# {'t': 'society ', 'n': 'society'}
# society
# which
# {'t': 'which ', 'n': 'which'}
# which
# cannot
# {'t': 'cannot ', 'n': 'cannot'}
# cannot
# cease
# {'t': 'cease ', 'n': 'cease'}
# cease
# to
# {'t': 'to ', 'n': 'to'}
# to
# be
# {'t': 'be ', 'n': 'be'}
# be
# regretted.
# {'t': 'regretted. ', 'n': 'regretted.'}
# regretted.
# i
# {'t': 'I ', 'n': 'i'}
# i
# passed
# {'t': 'passed ', 'n': 'passed'}
# passed
# the
# {'t': 'the ', 'n': 'the'}
# the
# summer
# {'t': 'summer ', 'n': 'summer'}
# summer
# of
# {'t': 'of ', 'n': 'of'}
# of
# 1816
# {'t': '1816 ', 'n': '1816'}
# 1816
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# environs
# {'t': 'environs ', 'n': 'environs'}
# environs
# of
# {'t': 'of ', 'n': 'of'}
# of
# geneva.
# {'t': 'Geneva. ', 'n': 'geneva.'}
# geneva.
# the
# {'t': 'The ', 'n': 'the'}
# the
# season
# {'t': 'season ', 'n': 'season'}
# season
# was
# {'t': 'was ', 'n': 'was'}
# was
# cold
# {'t': 'cold ', 'n': 'cold'}
# cold
# and
# {'t': 'and ', 'n': 'and'}
# and
# rainy,
# {'t': 'rainy, ', 'n': 'rainy,'}
# rainy,
# and
# {'t': 'and ', 'n': 'and'}
# and
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# evenings
# {'t': 'evenings ', 'n': 'evenings'}
# evenings
# we
# {'t': 'we ', 'n': 'we'}
# we
# crowded
# {'t': 'crowded ', 'n': 'crowded'}
# crowded
# around
# {'t': 'around ', 'n': 'around'}
# around
# a
# {'t': 'a ', 'n': 'a'}
# a
# blazing
# {'t': 'blazing ', 'n': 'blazing'}
# blazing
# wood
# {'t': 'wood ', 'n': 'wood'}
# wood
# fire,
# {'t': 'fire, ', 'n': 'fire,'}
# fire,
# and
# {'t': 'and ', 'n': 'and'}
# and
# occasionally
# {'t': 'occasionally ', 'n': 'occasionally'}
# occasionally
# amused
# {'t': 'amused ', 'n': 'amused'}
# amused
# ourselves
# {'t': 'ourselves ', 'n': 'ourselves'}
# ourselves
# with
# {'t': 'with ', 'n': 'with'}
# with
# some
# {'t': 'some ', 'n': 'some'}
# some
# german
# {'t': 'German ', 'n': 'german'}
# german
# stories
# {'t': 'stories ', 'n': 'stories'}
# stories
# of
# {'t': 'of ', 'n': 'of'}
# of
# ghosts,
# {'t': 'ghosts, ', 'n': 'ghosts,'}
# ghosts,
# which
# {'t': 'which ', 'n': 'which'}
# which
# happened
# {'t': 'happened ', 'n': 'happened'}
# happened
# to
# {'t': 'to ', 'n': 'to'}
# to
# fall
# {'t': 'fall ', 'n': 'fall'}
# fall
# into
# {'t': 'into ', 'n': 'into'}
# into
# our
# {'t': 'our ', 'n': 'our'}
# our
# hands.
# {'t': 'hands. ', 'n': 'hands.'}
# hands.
# these
# {'t': 'These ', 'n': 'these'}
# these
# tales
# {'t': 'tales ', 'n': 'tales'}
# tales
# excited
# {'t': 'excited ', 'n': 'excited'}
# excited
# in
# {'t': 'in ', 'n': 'in'}
# in
# us
# {'t': 'us ', 'n': 'us'}
# us
# a
# {'t': 'a ', 'n': 'a'}
# a
# playful
# {'t': 'playful ', 'n': 'playful'}
# playful
# desire
# {'t': 'desire ', 'n': 'desire'}
# desire
# of
# {'t': 'of ', 'n': 'of'}
# of
# imitation.
# {'t': 'imitation. ', 'n': 'imitation.'}
# imitation.
# two
# {'t': 'Two ', 'n': 'two'}
# two
# other
# {'t': 'other ', 'n': 'other'}
# other
# friends
# {'t': 'friends ', 'n': 'friends'}
# friends
# (a
# {'t': '(a ', 'n': '(a'}
# (a
# tale
# {'t': 'tale ', 'n': 'tale'}
# tale
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# pen
# {'t': 'pen ', 'n': 'pen'}
# pen
# of
# {'t': 'of ', 'n': 'of'}
# of
# one
# {'t': 'one ', 'n': 'one'}
# one
# of
# {'t': 'of ', 'n': 'of'}
# of
# whom
# {'t': 'whom ', 'n': 'whom'}
# whom
# would
# {'t': 'would ', 'n': 'would'}
# would
# be
# {'t': 'be ', 'n': 'be'}
# be
# far
# {'t': 'far ', 'n': 'far'}
# far
# more
# {'t': 'more ', 'n': 'more'}
# more
# acceptable
# {'t': 'acceptable ', 'n': 'acceptable'}
# acceptable
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# public
# {'t': 'public ', 'n': 'public'}
# public
# than
# {'t': 'than ', 'n': 'than'}
# than
# any
# {'t': 'any ', 'n': 'any'}
# any
# thing
# {'t': 'thing ', 'n': 'thing'}
# thing
# i
# {'t': 'I ', 'n': 'i'}
# i
# can
# {'t': 'can ', 'n': 'can'}
# can
# ever
# {'t': 'ever ', 'n': 'ever'}
# ever
# hope
# {'t': 'hope ', 'n': 'hope'}
# hope
# to
# ...
# {'t': 'whatever ', 'n': 'whatever'}
# whatever
# kind.
# {'t': 'kind. ', 'n': 'kind.'}
# kind.
# <p-end/>
# {'t': '<p eID="preface1_p3"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p4"/> ', 'n': '<p-start/>'}
# <p-start/>
# it
# {'t': 'It ', 'n': 'it'}
# it
# is
# {'t': 'is ', 'n': 'is'}
# is
# a
# {'t': 'a ', 'n': 'a'}
# a
# subject
# {'t': 'subject ', 'n': 'subject'}
# subject
# also
# {'t': 'also ', 'n': 'also'}
# also
# of
# {'t': 'of ', 'n': 'of'}
# of
# additional
# {'t': 'additional ', 'n': 'additional'}
# additional
# interest
# {'t': 'interest ', 'n': 'interest'}
# interest
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# author,
# {'t': 'author, ', 'n': 'author,'}
# author,
# that
# {'t': 'that ', 'n': 'that'}
# that
# this
# {'t': 'this ', 'n': 'this'}
# this
# story
# {'t': 'story ', 'n': 'story'}
# story
# was
# {'t': 'was ', 'n': 'was'}
# was
# begun
# {'t': 'begun ', 'n': 'begun'}
# begun
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# majestic
# {'t': 'majestic ', 'n': 'majestic'}
# majestic
# region
# {'t': 'region ', 'n': 'region'}
# region
# where
# {'t': 'where ', 'n': 'where'}
# where
# the
# {'t': 'the ', 'n': 'the'}
# the
# scene
# {'t': 'scene ', 'n': 'scene'}
# scene
# is
# {'t': 'is ', 'n': 'is'}
# is
# principally
# {'t': 'principally ', 'n': 'principally'}
# principally
# laid,
# {'t': 'laid, ', 'n': 'laid,'}
# laid,
# and
# {'t': 'and ', 'n': 'and'}
# and
# in
# {'t': 'in ', 'n': 'in'}
# in
# society
# {'t': 'society ', 'n': 'society'}
# society
# which
# {'t': 'which ', 'n': 'which'}
# which
# cannot
# {'t': 'cannot ', 'n': 'cannot'}
# cannot
# cease
# {'t': 'cease ', 'n': 'cease'}
# cease
# to
# {'t': 'to ', 'n': 'to'}
# to
# be
# {'t': 'be ', 'n': 'be'}
# be
# regretted.
# {'t': 'regretted. ', 'n': 'regretted.'}
# regretted.
# i
# {'t': 'I ', 'n': 'i'}
# i
# passed
# {'t': 'passed ', 'n': 'passed'}
# passed
# the
# {'t': 'the ', 'n': 'the'}
# the
# summer
# {'t': 'summer ', 'n': 'summer'}
# summer
# of
# {'t': 'of ', 'n': 'of'}
# of
# 1816
# {'t': '1816 ', 'n': '1816'}
# 1816
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# environs
# {'t': 'environs ', 'n': 'environs'}
# environs
# of
# {'t': 'of ', 'n': 'of'}
# of
# geneva.
# {'t': 'Geneva. ', 'n': 'geneva.'}
# geneva.
# the
# {'t': 'The ', 'n': 'the'}
# the
# season
# {'t': 'season ', 'n': 'season'}
# season
# was
# {'t': 'was ', 'n': 'was'}
# was
# cold
# {'t': 'cold ', 'n': 'cold'}
# cold
# and
# {'t': 'and ', 'n': 'and'}
# and
# rainy,
# {'t': 'rainy, ', 'n': 'rainy,'}
# rainy,
# and
# {'t': 'and ', 'n': 'and'}
# and
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# evenings
# {'t': 'evenings ', 'n': 'evenings'}
# evenings
# we
# {'t': 'we ', 'n': 'we'}
# we
# crowded
# {'t': 'crowded ', 'n': 'crowded'}
# crowded
# around
# {'t': 'around ', 'n': 'around'}
# around
# a
# {'t': 'a ', 'n': 'a'}
# a
# blazing
# {'t': 'blazing ', 'n': 'blazing'}
# blazing
# wood
# {'t': 'wood ', 'n': 'wood'}
# wood
# fire,
# {'t': 'fire, ', 'n': 'fire,'}
# fire,
# and
# {'t': 'and ', 'n': 'and'}
# and
# occasionally
# {'t': 'occasionally ', 'n': 'occasionally'}
# occasionally
# amused
# {'t': 'amused ', 'n': 'amused'}
# amused
# ourselves
# {'t': 'ourselves ', 'n': 'ourselves'}
# ourselves
# with
# {'t': 'with ', 'n': 'with'}
# with
# some
# {'t': 'some ', 'n': 'some'}
# some
# german
# {'t': 'German ', 'n': 'german'}
# german
# stories
# {'t': 'stories ', 'n': 'stories'}
# stories
# of
# {'t': 'of ', 'n': 'of'}
# of
# ghosts,
# {'t': 'ghosts, ', 'n': 'ghosts,'}
# ghosts,
# which
# {'t': 'which ', 'n': 'which'}
# which
# happened
# {'t': 'happened ', 'n': 'happened'}
# happened
# to
# {'t': 'to ', 'n': 'to'}
# to
# fall
# {'t': 'fall ', 'n': 'fall'}
# fall
# into
# {'t': 'into ', 'n': 'into'}
# into
# our
# {'t': 'our ', 'n': 'our'}
# our
# hands.
# {'t': 'hands. ', 'n': 'hands.'}
# hands.
# these
# {'t': 'These ', 'n': 'these'}
# these
# tales
# {'t': 'tales ', 'n': 'tales'}
# tales
# excited
# {'t': 'excited ', 'n': 'excited'}
# excited
# in
# {'t': 'in ', 'n': 'in'}
# in
# us
# {'t': 'us ', 'n': 'us'}
# us
# a
# {'t': 'a ', 'n': 'a'}
# a
# playful
# {'t': 'playful ', 'n': 'playful'}
# playful
# desire
# {'t': 'desire ', 'n': 'desire'}
# desire
# of
# {'t': 'of ', 'n': 'of'}
# of
# imitation.
# {'t': 'imitation. ', 'n': 'imitation.'}
# imitation.
# two
# {'t': 'Two ', 'n': 'two'}
# two
# other
# {'t': 'other ', 'n': 'other'}
# other
# friends
# {'t': 'friends ', 'n': 'friends'}
# friends
# (a
# {'t': '(a ', 'n': '(a'}
# (a
# tale
# {'t': 'tale ', 'n': 'tale'}
# tale
# from
# {'t': 'from ', 'n': 'from'}
# from
# the
# {'t': 'the ', 'n': 'the'}
# the
# pen
# {'t': 'pen ', 'n': 'pen'}
# pen
# of
# {'t': 'of ', 'n': 'of'}
# of
# one
# {'t': 'one ', 'n': 'one'}
# one
# of
# {'t': 'of ', 'n': 'of'}
# of
# whom
# {'t': 'whom ', 'n': 'whom'}
# whom
# would
# {'t': 'would ', 'n': 'would'}
# would
# be
# {'t': 'be ', 'n': 'be'}
# be
# far
# {'t': 'far ', 'n': 'far'}
# far
# more
# {'t': 'more ', 'n': 'more'}
# more
# acceptable
# {'t': 'acceptable ', 'n': 'acceptable'}
# acceptable
# to
# {'t': 'to ', 'n': 'to'}
# to
# the
# {'t': 'the ', 'n': 'the'}
# the
# public
# {'t': 'public ', 'n': 'public'}
# public
# than
# {'t': 'than ', 'n': 'than'}
# than
# any
# {'t': 'any ', 'n': 'any'}
# any
# thing
# {'t': 'thing ', 'n': 'thing'}
# thing
# i
# {'t': 'I ', 'n': 'i'}
# i
# can
# {'t': 'can ', 'n': 'can'}
# can
# ever
# {'t': 'ever ', 'n': 'ever'}
# ever
# hope
# {'t': 'hope ', 'n': 'hope'}
# hope
# to
# {'t': 'to ', 'n': 'to'}
# to
# produce)
# {'t': 'produce) ', 'n': 'produce)'}
# produce)
# and
# {'t': 'and ', 'n': 'and'}
# and
# myself
# {'t': 'myself ', 'n': 'myself'}
# myself
# agreed
# {'t': 'agreed ', 'n': 'agreed'}
# agreed
# to
# {'t': 'to ', 'n': 'to'}
# to
# write
# {'t': 'write ', 'n': 'write'}
# write
# each
# {'t': 'each ', 'n': 'each'}
# each
# a
# {'t': 'a ', 'n': 'a'}
# a
# story,
# {'t': 'story, ', 'n': 'story,'}
# story,
# founded
# {'t': 'founded ', 'n': 'founded'}
# founded
# on
# {'t': 'on ', 'n': 'on'}
# on
# some
# {'t': 'some ', 'n': 'some'}
# some
# supernatural
# {'t': 'supernatural ', 'n': 'supernatural'}
# supernatural
# occurrence.
# {'t': 'occurrence. ', 'n': 'occurrence.'}
# occurrence.
# <p-end/>
# {'t': '<p eID="preface1_p4"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p5"/> ', 'n': '<p-start/>'}
# <p-start/>
# the
# {'t': 'The ', 'n': 'the'}
# the
# weather,
# {'t': 'weather, ', 'n': 'weather,'}
# weather,
# however,
# {'t': 'however, ', 'n': 'however,'}
# however,
# suddenly
# {'t': 'suddenly ', 'n': 'suddenly'}
# suddenly
# became
# {'t': 'became ', 'n': 'became'}
# became
# serene;
# {'t': 'serene; ', 'n': 'serene;'}
# serene;
# and
# {'t': 'and ', 'n': 'and'}
# and
# my
# {'t': 'my ', 'n': 'my'}
# my
# two
# {'t': 'two ', 'n': 'two'}
# two
# friends
# {'t': 'friends ', 'n': 'friends'}
# friends
# left
# {'t': 'left ', 'n': 'left'}
# left
# me
# {'t': 'me ', 'n': 'me'}
# me
# on
# {'t': 'on ', 'n': 'on'}
# on
# a
# {'t': 'a ', 'n': 'a'}
# a
# journey
# {'t': 'journey ', 'n': 'journey'}
# journey
# among
# {'t': 'among ', 'n': 'among'}
# among
# the
# {'t': 'the ', 'n': 'the'}
# the
# alps,
# {'t': 'Alps, ', 'n': 'alps,'}
# alps,
# and
# {'t': 'and ', 'n': 'and'}
# and
# lost,
# {'t': 'lost, ', 'n': 'lost,'}
# lost,
# in
# {'t': 'in ', 'n': 'in'}
# in
# the
# {'t': 'the ', 'n': 'the'}
# the
# magnificent
# {'t': 'magnificent ', 'n': 'magnificent'}
# magnificent
# scenes
# {'t': 'scenes ', 'n': 'scenes'}
# scenes
# which
# {'t': 'which ', 'n': 'which'}
# which
# they
# {'t': 'they ', 'n': 'they'}
# they
# present,
# {'t': 'present, ', 'n': 'present,'}
# present,
# all
# {'t': 'all ', 'n': 'all'}
# all
# memory
# {'t': 'memory ', 'n': 'memory'}
# memory
# of
# {'t': 'of ', 'n': 'of'}
# of
# their
# {'t': 'their ', 'n': 'their'}
# their
# ghostly
# {'t': 'ghostly ', 'n': 'ghostly'}
# ghostly
# visions.
# {'t': 'visions. ', 'n': 'visions.'}
# visions.
# the
# {'t': 'The ', 'n': 'the'}
# the
# following
# {'t': 'following ', 'n': 'following'}
# following
# tale
# {'t': 'tale ', 'n': 'tale'}
# tale
# is
# {'t': 'is ', 'n': 'is'}
# is
# the
# {'t': 'the ', 'n': 'the'}
# the
# only
# {'t': 'only ', 'n': 'only'}
# only
# one
# {'t': 'one ', 'n': 'one'}
# one
# which
# {'t': 'which ', 'n': 'which'}
# which
# has
# {'t': 'has ', 'n': 'has'}
# has
# been
# {'t': 'been ', 'n': 'been'}
# been
# completed.
# {'t': 'completed. ', 'n': 'completed.'}
# completed.
# <p-end/>
# {'t': '<p eID="preface1_p5"/> ', 'n': '<p-end/>'}
# <p-end/>
# <p-start/>
# {'t': '<p sID="preface1_p6"/> ', 'n': '<p-start/>'}
# <p-start/>
# marlow,
# {'t': 'Marlow, ', 'n': 'marlow,'}
# marlow,
# september,
# {'t': 'September, ', 'n': 'september,'}
# september,
# 1817.
# {'t': '1817. ', 'n': '1817.'}
# 1817.
# <p-end/>
# {'t': '<p eID="preface1_p6"/> ', 'n': '<p-end/>'}
# <p-end/>
#
# {'t': '<milestone unit="preface" type="end" n="1"/> ', 'n': ''}
#
#
# {'t': ' ', 'n': ''}
#
#
# {'t': '<anchor type="collate" xml:id="C01"/> ', 'n': ''}
#
# {'id': 'fThomas', 'tokens': [{'t': ' ', 'n': ''}, {'t': '<milestone unit="volume" n="1"/> ', 'n': ''}, {'t': '<milestone unit="frontmatter" type="start" n="1"/> ', 'n': ''}, {'t': '<milestone unit="frontmatter" type="end" n="1"/> ', 'n': ''}, {'t': '<milestone unit="preface" type="start" n="1"/> ', 'n': ''}, {'t': '<pb xml:id="F1818_v1_007" n="viii"/> ', 'n': ''}, {'t': '<head>PREFACE.</head> ', 'n': 'preface.'}, {'t': '<p sID="preface1_p1"/> ', 'n': '<p-start/>'}, {'t': 'T<hi sID="preface1_p1_hi1"/>HE<hi eID="preface1_p1_hi1"/> ', 'n': 't<hi>he</hi>'}, {'t': 'event ', 'n': 'event'}, {'t': 'on ', 'n': 'on'}, {'t': 'which ', 'n': 'which'}, {'t': 'this ', 'n': 'this'}, {'t': 'fiction ', 'n': 'fiction'}, {'t': 'is ', 'n': 'is'}, {'t': 'founded ', 'n': 'founded'}, {'t': 'has ', 'n': 'has'}, {'t': 'been ', 'n': 'been'}, {'t': 'supposed, ', 'n': 'supposed,'}, {'t': 'by ', 'n': 'by'}, {'t': 'Dr. ', 'n': 'dr.'}, {'t': 'Darwin, ', 'n': 'darwin,'}, {'t': 'and ', 'n': 'and'}, {'t': 'some ', 'n': 'some'}, {'t': 'of ', 'n': 'of'}, {'t': 'the ', 'n': 'the'}, {'t': 'physiological ', 'n': 'physiological'}, {'t': 'writers ', 'n': 'writers'}, {'t': 'of ', 'n': 'of'}, {'t': 'Germany, ', 'n': 'germany,'}, {'t': 'as ', 'n': 'as'}, {'t': 'not ', 'n': 'not'}, {'t': 'of ', 'n': 'of'}, {'t': 'impossible ', 'n': 'impossible'}, {'t': 'occurrence. ', 'n': 'occurrence.'}, {'t': 'I ', 'n': 'i'}, {'t': 'shall ', 'n': 'shall'}, {'t': 'not ', 'n': 'not'}, {'t': 'be ', 'n': 'be'}, {'t': 'supposed ', 'n': 'supposed'}, {'t': 'as ', 'n': 'as'}, {'t': 'according ', 'n': 'according'}, {'t': 'the ', 'n': 'the'}, {'t': 'remotest ', 'n': 'remotest'}, {'t': 'degree ', 'n': 'degree'}, {'t': 'of ', 'n': 'of'}, {'t': 'serious ', 'n': 'serious'}, {'t': 'faith ', 'n': 'faith'}, {'t': 'to ', 'n': 'to'}, {'t': 'such ', 'n': 'such'}, {'t': 'an ', 'n': 'an'}, {'t': 'imagination; ', 'n': 'imagination;'}, {'t': 'yet, ', 'n': 'yet,'}, {'t': 'in ', 'n': 'in'}, {'t': 'assuming ', 'n': 'assuming'}, {'t': 'it ', 'n': 'it'}, {'t': 'as ', 'n': 'as'}, {'t': 'the ', 'n': 'the'}, {'t': 'basis ', 'n': 'basis'}, {'t': 'of ', 'n': 'of'}, {'t': 'a ', 'n': 'a'}, {'t': 'work ', 'n': 'work'}, {'t': 'of ', 'n': 'of'}, {'t': 'fancy, ', 'n': 'fancy,'}, {'t': 'I ', 'n': 'i'}, {'t': 'have ', 'n': 'have'}, {'t': 'not ', 'n': 'not'}, {'t': 'considered ', 'n': 'considered'}, {'t': 'myself ', 'n': 'myself'}, {'t': 'as ', 'n': 'as'}, {'t': 'merely ', 'n': 'merely'}, {'t': 'weaving ', 'n': 'weaving'}, {'t': 'a ', 'n': 'a'}, {'t': 'series ', 'n': 'series'}, {'t': 'of ', 'n': 'of'}, {'t': 'supernatural ', 'n': 'supernatural'}, {'t': 'terrors. ', 'n': 'terrors.'}, {'t': 'The ', 'n': 'the'}, {'t': 'event ', 'n': 'event'}, {'t': 'on ', 'n': 'on'}, {'t': '<pb xml:id="F1818_v1_008" n="viii"/>which ', 'n': 'which'}, {'t': 'the ', 'n': 'the'}, {'t': 'interest ', 'n': 'interest'}, {'t': 'of ', 'n': 'of'}, {'t': 'the ', 'n': 'the'}, {'t': 'story ', 'n': 'story'}, {'t': 'depends ', 'n': 'depends'}, {'t': 'is ', 'n': 'is'}, {'t': 'exempt ', 'n': 'exempt'}, {'t': 'from ', 'n': 'from'}, {'t': 'the ', 'n': 'the'}, {'t': 'disadvantages ', 'n': 'disadvantages'}, {'t': 'of ', 'n': 'of'}, {'t': 'a ', 'n': 'a'}, {'t': 'mere ', 'n': 'mere'}, {'t': 'tale ', 'n': 'tale'}, {'t': 'of ', 'n': 'of'}, {'t': 'spectres ', 'n': 'spectres'}, {'t': 'or ', 'n': 'or'}, {'t': 'enchantment. ', 'n': 'enchantment.'}, {'t': 'It ', 'n': 'it'}, {'t': 'was ', 'n': 'was'}, {'t': 'recommended ', 'n': 'recommended'}, {'t': 'by ', 'n': 'by'}, {'t': 'the ', 'n': 'the'}, {'t': 'novelty ', 'n': 'novelty'}, {'t': 'of ', 'n': 'of'}, {'t': 'the ', 'n': 'the'}, {'t': 'situations ', 'n': 'situations'}, {'t': 'which ', 'n': 'which'}, {'t': 'it ', 'n': 'it'}, {'t': 'developes; ', 'n': 'developes;'}, {'t': 'and, ', 'n': 'and,'}, {'t': 'however ', 'n': 'however'}, {'t': 'impossible ', 'n': 'impossible'}, {'t': 'as ', 'n': 'as'}, {'t': 'a ', 'n': 'a'}, {'t': 'physical ', 'n': 'physical'}, {'t': 'fact, ', 'n': 'fact,'}, {'t': 'affords ', 'n': 'affords'}, {'t': 'a ', ' ...
# [{'id': 'f1818', 'tokens': [{'t': ' ', 'n': ''}, {'t': '<milestone unit="volume" n="1"/> ', 'n': ''}, {'t': '<milestone unit="frontmatter" type="start" n="1"/> ', 'n': ''}, {'t': '<milestone unit="frontmatter" type="end" n="1"/> ', 'n': ''}, {'t': '<milestone unit="preface" type="start" n="1"/> ', 'n': ''}, {'t': '<pb xml:id="F1818_v1_007" n="viii"/> ', 'n': ''}, {'t': '<head>PREFACE.</head> ', 'n': 'preface.'}, {'t': '<p sID="preface1_p1"/> ', 'n': '<p-start/>'}, {'t': 'T<hi sID="preface1_p1_hi1"/>HE<hi eID="preface1_p1_hi1"/> ', 'n': 't<hi>he</hi>'}, {'t': 'event ', 'n': 'event'}, {'t': 'on ', 'n': 'on'}, {'t': 'which ', 'n': 'which'}, {'t': 'this ', 'n': 'this'}, {'t': 'fiction ', 'n': 'fiction'}, {'t': 'is ', 'n': 'is'}, {'t': 'founded ', 'n': 'founded'}, {'t': 'has ', 'n': 'has'}, {'t': 'been ', 'n': 'been'}, {'t': 'supposed, ', 'n': 'supposed,'}, {'t': 'by ', 'n': 'by'}, {'t': 'Dr. ', 'n': 'dr.'}, {'t': 'Darwin, ', 'n': 'darwin,'}, {'t': 'and ', 'n': 'and'}, {'t': 'some ', 'n': 'some'}, {'t': 'of ', 'n': 'of'}, {'t': 'the ', 'n': 'the'}, {'t': 'physiological ', 'n': 'physiological'}, {'t': 'writers ', 'n': 'writers'}, {'t': 'of ', 'n': 'of'}, {'t': 'Germany, ', 'n': 'germany,'}, {'t': 'as ', 'n': 'as'}, {'t': 'not ', 'n': 'not'}, {'t': 'of ', 'n': 'of'}, {'t': 'impossible ', 'n': 'impossible'}, {'t': 'occurrence. ', 'n': 'occurrence.'}, {'t': 'I ', 'n': 'i'}, {'t': 'shall ', 'n': 'shall'}, {'t': 'not ', 'n': 'not'}, {'t': 'be ', 'n': 'be'}, {'t': 'supposed ', 'n': 'supposed'}, {'t': 'as ', 'n': 'as'}, {'t': 'according ', 'n': 'according'}, {'t': 'the ', 'n': 'the'}, {'t': 'remotest ', 'n': 'remotest'}, {'t': 'degree ', 'n': 'degree'}, {'t': 'of ', 'n': 'of'}, {'t': 'serious ', 'n': 'serious'}, {'t': 'faith ', 'n': 'faith'}, {'t': 'to ', 'n': 'to'}, {'t': 'such ', 'n': 'such'}, {'t': 'an ', 'n': 'an'}, {'t': 'imagination; ', 'n': 'imagination;'}, {'t': 'yet, ', 'n': 'yet,'}, {'t': 'in ', 'n': 'in'}, {'t': 'assuming ', 'n': 'assuming'}, {'t': 'it ', 'n': 'it'}, {'t': 'as ', 'n': 'as'}, {'t': 'the ', 'n': 'the'}, {'t': 'basis ', 'n': 'basis'}, {'t': 'of ', 'n': 'of'}, {'t': 'a ', 'n': 'a'}, {'t': 'work ', 'n': 'work'}, {'t': 'of ', 'n': 'of'}, {'t': 'fancy, ', 'n': 'fancy,'}, {'t': 'I ', 'n': 'i'}, {'t': 'have ', 'n': 'have'}, {'t': 'not ', 'n': 'not'}, {'t': 'considered ', 'n': 'considered'}, {'t': 'myself ', 'n': 'myself'}, {'t': 'as ', 'n': 'as'}, {'t': 'merely ', 'n': 'merely'}, {'t': 'weaving ', 'n': 'weaving'}, {'t': 'a ', 'n': 'a'}, {'t': 'series ', 'n': 'series'}, {'t': 'of ', 'n': 'of'}, {'t': 'supernatural ', 'n': 'supernatural'}, {'t': 'terrors. ', 'n': 'terrors.'}, {'t': 'The ', 'n': 'the'}, {'t': 'event ', 'n': 'event'}, {'t': 'on ', 'n': 'on'}, {'t': '<pb xml:id="F1818_v1_008" n="viii"/>which ', 'n': 'which'}, {'t': 'the ', 'n': 'the'}, {'t': 'interest ', 'n': 'interest'}, {'t': 'of ', 'n': 'of'}, {'t': 'the ', 'n': 'the'}, {'t': 'story ', 'n': 'story'}, {'t': 'depends ', 'n': 'depends'}, {'t': 'is ', 'n': 'is'}, {'t': 'exempt ', 'n': 'exempt'}, {'t': 'from ', 'n': 'from'}, {'t': 'the ', 'n': 'the'}, {'t': 'disadvantages ', 'n': 'disadvantages'}, {'t': 'of ', 'n': 'of'}, {'t': 'a ', 'n': 'a'}, {'t': 'mere ', 'n': 'mere'}, {'t': 'tale ', 'n': 'tale'}, {'t': 'of ', 'n': 'of'}, {'t': 'spectres ', 'n': 'spectres'}, {'t': 'or ', 'n': 'or'}, {'t': 'enchantment. ', 'n': 'enchantment.'}, {'t': 'It ', 'n': 'it'}, {'t': 'was ', 'n': 'was'}, {'t': 'recommended ', 'n': 'recommended'}, {'t': 'by ', 'n': 'by'}, {'t': 'the ', 'n': 'the'}, {'t': 'novelty ', 'n': 'novelty'}, {'t': 'of ', 'n': 'of'}, {'t': 'the ', 'n': 'the'}, {'t': 'situations ', 'n': 'situations'}, {'t': 'which ', 'n': 'which'}, {'t': 'it ', 'n': 'it'}, {'t': 'developes; ', 'n': 'developes;'}, {'t': 'and, ', 'n': 'and,'}, {'t': 'however ', 'n': 'however'}, {'t': 'impossible ', 'n': 'impossible'}, {'t': 'as ', 'n': 'as'}, {'t': 'a ', 'n': 'a'}, {'t': 'physical ', 'n': 'physical'}, {'t': 'fact, ', 'n': 'fact,'}, {'t': 'affords ', 'n': 'affords'}, {'t': 'a ', 'n ...
